# %% [markdown]
# # CatBoost basics

# %% [markdown]
# For this homework will use dataset Amazon Employee Access Challenge from [Kaggle](https://www.kaggle.com) competition for our experiments. Data can be downloaded [here](https://www.kaggle.com/c/amazon-employee-access-challenge/data).

# %% [markdown]
# As a result of this tutorial you need to provide a tsv file with answers.
# There are 17 questions in this tutorial. The resulting tsv file should consist of 17 lines, each line should contain the number of the question, an answer to it and a tab separater between them. Questions are numbered from 1 to 17.
# See an example of the resulting file here.

# %% [markdown]
# ## Reading the data

# %% [markdown]
# Let's first download the data and put it to folder `amazon`. Now we will read this data from file.

# %%
import pandas as pd
import numpy as np

np.set_printoptions(precision=4)
import catboost
from catboost import datasets
from catboost import *

from grader_v2 import Grader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c1e4e25e9de2> in <module>()
#       3
#       4 np.set_printoptions(precision=4)
# ----> 5 import catboost
#       6 from catboost import datasets
#       7 from catboost import *
#
# ModuleNotFoundError: No module named 'catboost'

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading https://files.pythonhosted.org/packages/8b/d9/f4a5a9b045fb8b33a5e245787c1b146307474400a83ff290742350f2d92b/catboost-0.15.1-cp36-none-win_amd64.whl (60.7MB)
# Collecting numpy>=1.16.0 (from catboost)
#   Downloading https://files.pythonhosted.org/packages/20/ed/e036d31a9b2c750f270cbb1cfc1c0f94ac78ae504eea7eec3267be4e294a/numpy-1.16.4-cp36-cp36m-win_amd64.whl (11.9MB)
# Requirement already satisfied: six in c:\users\victorvt\anaconda3\lib\site-packages (from catboost) (1.11.0)
# Collecting graphviz (from catboost)
#   Downloading https://files.pythonhosted.org/packages/af/ae/e1c63ac4c531d69a7960a99af99e184d4f3da15e29f67767c4252bf19cce/graphviz-0.11-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.19.1 in c:\users\victorvt\anaconda3\lib\site-packages (from catboost) (0.23.4)
# Requirement already satisfied: pytz>=2011k in c:\users\victorvt\anaconda3\lib\site-packages (from pandas>=0.19.1->catboost) (2018.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\victorvt\anaconda3\lib\site-packages (from pandas>=0.19.1->catboost) (2.7.3)
# Installing collected packages: numpy, graphviz, catboost
#   Found existing installation: numpy 1.15.4
#     Uninstalling numpy-1.15.4:
#       Successfully uninstalled numpy-1.15.4
# ERROR: tensorflow-gpu 1.9.0 has requirement tensorboard<1.10.0,>=1.9.0, but you'll have tensorboard 1.8.0 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\victorvt\\anaconda3\\lib\\site-packages\\~umpy\\.libs\\libopenblas.BNVRK7633HSX7YVO2TADGR4A5KEKXJAW.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.

# %%
train_df, test_df = catboost.datasets.amazon()
train_df.head()
# Out:
#    ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0       1     39353   85475         117961         118300         123472
# 1       1     17183    1540         117961         118343         123125
# 2       1     36724   14457         118219         118220         117884
# 3       1     36135    5396         117961         118343         119993
# 4       1     42680    5905         117929         117930         119569
#
#    ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0      117905            117906       290919     117908
# 1      118536            118536       308574     118539
# 2      117879            267952        19721     117880
# 3      118321            240983       290919     118322
# 4      119323            123932        19793     119325

# %%
grader = Grader()

# %% [markdown]
# ## Preparing your data

# %% [markdown]
# Label values extraction

# %%
y = train_df.ACTION
X = train_df.drop('ACTION', axis=1)

# %% [markdown]
# Categorical features declaration

# %%
cat_features = list(range(0, X.shape[1]))
print(cat_features)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# Now it makes sense to ananyze the dataset.
# First you need to calculate how many positive and negative objects are present in the train dataset.

# %% [markdown]
# **Question 1:**
#
# How many negative objects are present in the train dataset X?

# %%
y.value_counts()
# Out:
# 1    30872
# 0     1897
# Name: ACTION, dtype: int64

# %%
zero_count = 1897
grader.submit_tag('negative_samples', zero_count)
# Out:
# Current answer for task negative_samples is: 1897

# %% [markdown]
# **Question 2:**
#
# How many positive objects are present in the train dataset X?

# %%
one_count = 30872
grader.submit_tag('positive_samples', one_count)
# Out:
# Current answer for task positive_samples is: 30872

# %%
print('Zero count = ' + str(zero_count) + ', One count = ' + str(one_count))
# Out:
# Zero count = 1897, One count = 30872

# %% [markdown]
# Now for every feature you need to calculate number of unique values of this feature.

# %% [markdown]
# **Question 3:**
#
# How many unique values has feature RESOURCE?

# %%
unique_vals_for_RESOURCE = len(X.RESOURCE.unique())
grader.submit_tag('resource_unique_values', unique_vals_for_RESOURCE)
# Out:
# Current answer for task resource_unique_values is: 7518

# %% [markdown]
# Now we can create a Pool object. This type is used for datasets in CatBoost. You can also use numpy array or dataframe. Working with Pool class is the most efficient way in terms of memory and speed. We recommend to create Pool from file in case if you have your data on disk or from FeaturesData if you use numpy.

# %%
import numpy as np
from catboost import Pool

pool1 = Pool(data=X, label=y, cat_features=cat_features)
pool2 = Pool(data='/opt/conda/lib/python3.6/site-packages/catboost/cached_datasets/amazon/train.csv', delimiter=',', has_header=True)
pool3 = Pool(data=X, cat_features=cat_features)

print('Dataset shape')
print('dataset 1:' + str(pool1.shape) + '\ndataset 2:' + str(pool2.shape)  + '\ndataset 3:' + str(pool3.shape))

print('\n')
print('Column names')
print('dataset 1: ')
print(pool1.get_feature_names()) 
print('\ndataset 2:')
print(pool2.get_feature_names())
print('\ndataset 3:')
print(pool3.get_feature_names())
# Out:
# Dataset shape
# dataset 1:(32769, 9)
# dataset 2:(32769, 9)
# dataset 3:(32769, 9)
#
#
# Column names
# dataset 1:
# ['RESOURCE', 'MGR_ID', 'ROLE_ROLLUP_1', 'ROLE_ROLLUP_2', 'ROLE_DEPTNAME', 'ROLE_TITLE', 'ROLE_FAMILY_DESC', 'ROLE_FAMILY', 'ROLE_CODE']
#
# dataset 2:
# ['RESOURCE', 'MGR_ID', 'ROLE_ROLLUP_1', 'ROLE_ROLLUP_2', 'ROLE_DEPTNAME', 'ROLE_TITLE', 'ROLE_FAMILY_DESC', 'ROLE_FAMILY', 'ROLE_CODE']
#
# dataset 3:
# ['RESOURCE', 'MGR_ID', 'ROLE_ROLLUP_1', 'ROLE_ROLLUP_2', 'ROLE_DEPTNAME', 'ROLE_TITLE', 'ROLE_FAMILY_DESC', 'ROLE_FAMILY', 'ROLE_CODE']

# %% [markdown]
# ## Split your data into train and validation

# %% [markdown]
# When you will be training your model, you will have to detect overfitting and select best parameters. To do that you need to have a validation dataset.
# Normally you would be using some random split, for example
# `train_test_split` from `sklearn.model_selection`.
# But for the purpose of this homework the train part will be the first 80% of the data and the evaluation part will be the last 20% of the data.

# %%
train_count = int(X.shape[0] * 0.8)

X_train = X.iloc[:train_count,:]
y_train = y[:train_count]
X_validation = X.iloc[train_count:, :]
y_validation = y[train_count:]

# %% [markdown]
# ## Train your model

# %% [markdown]
# Now we will train our first model.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=5,
    random_seed=0,
    learning_rate=0.1
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
    logging_level='Silent'
)
print('Model is fitted: ' + str(model.is_fitted()))
print('Model params:')
print(model.get_params())
# Out:
# Model is fitted: True
# Model params:
# {'random_seed': 0, 'loss_function': 'Logloss', 'learning_rate': 0.1, 'iterations': 5}

# %% [markdown]
# ## Stdout of the training

# %% [markdown]
# You can see in stdout values of the loss function on each iteration, or on each k-th iteration.
# You can also see how much time passed since the start of the training and how much time is left.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=15,
    verbose=3
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
)
# Out:
# 0:	learn: 0.3007996	test: 0.3044268	best: 0.3044268 (0)	total: 126ms	remaining: 1.76s
# 3:	learn: 0.1800237	test: 0.1674121	best: 0.1674121 (3)	total: 1.82s	remaining: 5.02s
# 6:	learn: 0.1706950	test: 0.1549520	best: 0.1549520 (6)	total: 3.23s	remaining: 3.69s
# 9:	learn: 0.1672391	test: 0.1495040	best: 0.1495040 (9)	total: 4.43s	remaining: 2.22s
# 12:	learn: 0.1645499	test: 0.1487789	best: 0.1487789 (12)	total: 6.03s	remaining: 927ms
# 14:	learn: 0.1630092	test: 0.1469375	best: 0.1469375 (14)	total: 7.12s	remaining: 0us
#
# bestTest = 0.1469374586
# bestIteration = 14

# %% [markdown]
# ## Random seed

# %% [markdown]
# If you don't specify random_seed then random seed will be set to a new value each time.
# After the training has finished you can look on the value of the random seed that was set.
# If you train again with this random_seed, you will get the same results.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=5
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
)
# Out:
# 0:	learn: 0.3007996	test: 0.3044268	best: 0.3044268 (0)	total: 131ms	remaining: 523ms
# 1:	learn: 0.2161146	test: 0.2152075	best: 0.2152075 (1)	total: 733ms	remaining: 1.1s
# 2:	learn: 0.1879597	test: 0.1797290	best: 0.1797290 (2)	total: 1.23s	remaining: 820ms
# 3:	learn: 0.1800237	test: 0.1674121	best: 0.1674121 (3)	total: 1.83s	remaining: 458ms
# 4:	learn: 0.1732668	test: 0.1581682	best: 0.1581682 (4)	total: 2.44s	remaining: 0us
#
# bestTest = 0.1581682309
# bestIteration = 4

# %%
random_seed = model.random_seed_
print('Used random seed = ' + str(random_seed))
model = CatBoostClassifier(
    iterations=5,
    random_seed=random_seed
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
)
# Out:
# Used random seed = 0
# 0:	learn: 0.3007996	test: 0.3044268	best: 0.3044268 (0)	total: 135ms	remaining: 539ms
# 1:	learn: 0.2161146	test: 0.2152075	best: 0.2152075 (1)	total: 736ms	remaining: 1.1s
# 2:	learn: 0.1879597	test: 0.1797290	best: 0.1797290 (2)	total: 1.23s	remaining: 822ms
# 3:	learn: 0.1800237	test: 0.1674121	best: 0.1674121 (3)	total: 1.83s	remaining: 459ms
# 4:	learn: 0.1732668	test: 0.1581682	best: 0.1581682 (4)	total: 2.44s	remaining: 0us
#
# bestTest = 0.1581682309
# bestIteration = 4

# %% [markdown]
# Try training 10 models with parameters and calculate mean and the standart deviation of Logloss error on validation dataset.

# %% [markdown]
# **Question 4:**
#
# What is the mean value of the Logloss metric on validation dataset (X_validation, y_validation) after 10 times training `CatBoostClassifier` with different random seeds in the following way:
#
# `model = CatBoostClassifier(
#     iterations=300,
#     learning_rate=0.1,
#     random_seed={my_random_seed}
# )
# model.fit(
#     X_train, y_train,
#     cat_features=cat_features,
#     eval_set=(X_validation, y_validation),
# )
# `

# %%
random_state = [43, 10, 5, 42, 20, 21, 32, 189, 87, 29]
logloss = []
for rs in random_state:
    model = CatBoostClassifier(
        iterations=300,
        learning_rate=0.1,
        random_seed=rs
    )
    model.fit(
        X_train, y_train,
        cat_features=cat_features,
        eval_set=(X_validation, y_validation),
    )
    logloss.append(model.best_score_['validation_0']['Logloss'])
# Out:
# 0:	learn: 0.5789239	test: 0.5797609	best: 0.5797609 (0)	total: 285ms	remaining: 1m 25s
# 1:	learn: 0.4900493	test: 0.4908600	best: 0.4908600 (1)	total: 684ms	remaining: 1m 41s
# 2:	learn: 0.4254297	test: 0.4269242	best: 0.4269242 (2)	total: 1.08s	remaining: 1m 47s
# 3:	learn: 0.3760418	test: 0.3785396	best: 0.3785396 (3)	total: 1.58s	remaining: 1m 56s
# 4:	learn: 0.3382915	test: 0.3411180	best: 0.3411180 (4)	total: 1.98s	remaining: 1m 56s
# 5:	learn: 0.3096694	test: 0.3127215	best: 0.3127215 (5)	total: 2.48s	remaining: 2m 1s
# 6:	learn: 0.2887332	test: 0.2921224	best: 0.2921224 (6)	total: 2.99s	remaining: 2m 5s
# 7:	learn: 0.2714190	test: 0.2746836	best: 0.2746836 (7)	total: 3.48s	remaining: 2m 7s
# 8:	learn: 0.2527506	test: 0.2542535	best: 0.2542535 (8)	total: 3.98s	remaining: 2m 8s
# 9:	learn: 0.2380506	test: 0.2381689	best: 0.2381689 (9)	total: 4.38s	remaining: 2m 7s
# 10:	learn: 0.2254809	test: 0.2241849	best: 0.2241849 (10)	total: 4.88s	remaining: 2m 8s
# 11:	learn: 0.2139901	test: 0.2106395	best: 0.2106395 (11)	total: 5.49s	remaining: 2m 11s
# 12:	learn: 0.2062203	test: 0.2016636	best: 0.2016636 (12)	total: 5.98s	remaining: 2m 12s
# 13:	learn: 0.2001268	test: 0.1943845	best: 0.1943845 (13)	total: 6.39s	remaining: 2m 10s
# 14:	learn: 0.1954382	test: 0.1887380	best: 0.1887380 (14)	total: 6.78s	remaining: 2m 8s
# 15:	learn: 0.1918852	test: 0.1842234	best: 0.1842234 (15)	total: 7.18s	remaining: 2m 7s
# 16:	learn: 0.1887412	test: 0.1802148	best: 0.1802148 (16)	total: 7.58s	remaining: 2m 6s
# 17:	learn: 0.1859347	test: 0.1763504	best: 0.1763504 (17)	total: 8.08s	remaining: 2m 6s
# 18:	learn: 0.1836786	test: 0.1732109	best: 0.1732109 (18)	total: 8.58s	remaining: 2m 6s
# 19:	learn: 0.1818401	test: 0.1705286	best: 0.1705286 (19)	total: 9.18s	remaining: 2m 8s
# 20:	learn: 0.1799259	test: 0.1675505	best: 0.1675505 (20)	total: 9.68s	remaining: 2m 8s
# 21:	learn: 0.1787080	test: 0.1659293	best: 0.1659293 (21)	total: 10.3s	remaining: 2m 9s
# 22:	learn: 0.1772160	test: 0.1637869	best: 0.1637869 (22)	total: 10.9s	remaining: 2m 11s
# 23:	learn: 0.1754051	test: 0.1615991	best: 0.1615991 (23)	total: 11.6s	remaining: 2m 13s
# 24:	learn: 0.1746108	test: 0.1604608	best: 0.1604608 (24)	total: 12.2s	remaining: 2m 13s
# 25:	learn: 0.1733539	test: 0.1589286	best: 0.1589286 (25)	total: 12.9s	remaining: 2m 15s
# 26:	learn: 0.1729209	test: 0.1581978	best: 0.1581978 (26)	total: 13.4s	remaining: 2m 15s
# 27:	learn: 0.1721981	test: 0.1572611	best: 0.1572611 (27)	total: 13.9s	remaining: 2m 14s
# 28:	learn: 0.1713019	test: 0.1561919	best: 0.1561919 (28)	total: 14.4s	remaining: 2m 14s
# 29:	learn: 0.1704645	test: 0.1554274	best: 0.1554274 (29)	total: 15s	remaining: 2m 14s
# 30:	learn: 0.1696394	test: 0.1542958	best: 0.1542958 (30)	total: 15.5s	remaining: 2m 14s
# 31:	learn: 0.1693142	test: 0.1538191	best: 0.1538191 (31)	total: 16s	remaining: 2m 13s
# 32:	learn: 0.1686602	test: 0.1529867	best: 0.1529867 (32)	total: 16.6s	remaining: 2m 14s
# 33:	learn: 0.1676453	test: 0.1516073	best: 0.1516073 (33)	total: 17.3s	remaining: 2m 15s
# 34:	learn: 0.1666449	test: 0.1502153	best: 0.1502153 (34)	total: 17.9s	remaining: 2m 15s
# 35:	learn: 0.1658545	test: 0.1493056	best: 0.1493056 (35)	total: 18.6s	remaining: 2m 16s
# 36:	learn: 0.1652339	test: 0.1486045	best: 0.1486045 (36)	total: 19.2s	remaining: 2m 16s
# 37:	learn: 0.1644364	test: 0.1478757	best: 0.1478757 (37)	total: 19.8s	remaining: 2m 16s
# 38:	learn: 0.1635887	test: 0.1468028	best: 0.1468028 (38)	total: 20.4s	remaining: 2m 16s
# 39:	learn: 0.1631969	test: 0.1464705	best: 0.1464705 (39)	total: 21.1s	remaining: 2m 16s
# 40:	learn: 0.1631230	test: 0.1464243	best: 0.1464243 (40)	total: 21.4s	remaining: 2m 15s
# 41:	learn: 0.1627248	test: 0.1459279	best: 0.1459279 (41)	total: 22s	remaining: 2m 14s
# 42:	learn: 0.1622642	test: 0.1453334	best: 0.1453334 (42)	total: 22.6s	remaining: 2m 14s
# 43:	learn: 0.1620466	test: 0.1452161	best: 0.1452161 (43)	total: 23.2s	remaining: 2m 14s
# 44:	learn: 0.1613402	test: 0.1446508	best: 0.1446508 (44)	total: 23.9s	remaining: 2m 15s
# 45:	learn: 0.1609557	test: 0.1442058	best: 0.1442058 (45)	total: 24.5s	remaining: 2m 15s
# 46:	learn: 0.1608920	test: 0.1440831	best: 0.1440831 (46)	total: 24.9s	remaining: 2m 13s
# 47:	learn: 0.1605580	test: 0.1437770	best: 0.1437770 (47)	total: 25.5s	remaining: 2m 13s
# 48:	learn: 0.1602028	test: 0.1434456	best: 0.1434456 (48)	total: 26.1s	remaining: 2m 13s
# 49:	learn: 0.1600914	test: 0.1433878	best: 0.1433878 (49)	total: 26.7s	remaining: 2m 13s
# 50:	learn: 0.1599913	test: 0.1433755	best: 0.1433755 (50)	total: 27.3s	remaining: 2m 13s
# 51:	learn: 0.1597686	test: 0.1430679	best: 0.1430679 (51)	total: 27.9s	remaining: 2m 12s
# 52:	learn: 0.1595993	test: 0.1428890	best: 0.1428890 (52)	total: 28.5s	remaining: 2m 12s
# 53:	learn: 0.1590499	test: 0.1425188	best: 0.1425188 (53)	total: 29.2s	remaining: 2m 12s
# 54:	learn: 0.1586459	test: 0.1422110	best: 0.1422110 (54)	total: 29.8s	remaining: 2m 12s
# 55:	learn: 0.1585344	test: 0.1420295	best: 0.1420295 (55)	total: 30.2s	remaining: 2m 11s
# 56:	learn: 0.1581528	test: 0.1418541	best: 0.1418541 (56)	total: 30.8s	remaining: 2m 11s
# 57:	learn: 0.1580415	test: 0.1416793	best: 0.1416793 (57)	total: 31.4s	remaining: 2m 10s
# 58:	learn: 0.1579008	test: 0.1416384	best: 0.1416384 (58)	total: 32s	remaining: 2m 10s
# 59:	learn: 0.1578910	test: 0.1416387	best: 0.1416384 (58)	total: 32.3s	remaining: 2m 9s
# 60:	learn: 0.1578769	test: 0.1416074	best: 0.1416074 (60)	total: 32.8s	remaining: 2m 8s
# 61:	learn: 0.1577446	test: 0.1415867	best: 0.1415867 (61)	total: 33.4s	remaining: 2m 8s
# 62:	learn: 0.1573540	test: 0.1412800	best: 0.1412800 (62)	total: 34s	remaining: 2m 7s
# 63:	learn: 0.1572314	test: 0.1411560	best: 0.1411560 (63)	total: 34.5s	remaining: 2m 7s
# 64:	learn: 0.1570973	test: 0.1411083	best: 0.1411083 (64)	total: 35.1s	remaining: 2m 6s
# 65:	learn: 0.1569935	test: 0.1411215	best: 0.1411083 (64)	total: 35.6s	remaining: 2m 6s
# 66:	learn: 0.1569799	test: 0.1410983	best: 0.1410983 (66)	total: 36s	remaining: 2m 5s
# 67:	learn: 0.1568487	test: 0.1411472	best: 0.1410983 (66)	total: 36.6s	remaining: 2m 4s
# 68:	learn: 0.1566889	test: 0.1411123	best: 0.1410983 (66)	total: 37.2s	remaining: 2m 4s
# 69:	learn: 0.1565586	test: 0.1411244	best: 0.1410983 (66)	total: 37.8s	remaining: 2m 4s
# 70:	learn: 0.1564080	test: 0.1410720	best: 0.1410720 (70)	total: 38.4s	remaining: 2m 3s
# 71:	learn: 0.1563973	test: 0.1410727	best: 0.1410720 (70)	total: 38.8s	remaining: 2m 2s
# 72:	learn: 0.1563882	test: 0.1410856	best: 0.1410720 (70)	total: 39.1s	remaining: 2m 1s
# 73:	learn: 0.1563533	test: 0.1411305	best: 0.1410720 (70)	total: 39.6s	remaining: 2m
# 74:	learn: 0.1562125	test: 0.1409978	best: 0.1409978 (74)	total: 40.2s	remaining: 2m
# 75:	learn: 0.1560546	test: 0.1409059	best: 0.1409059 (75)	total: 40.8s	remaining: 2m
# 76:	learn: 0.1556364	test: 0.1406851	best: 0.1406851 (76)	total: 41.4s	remaining: 1m 59s
# 77:	learn: 0.1556070	test: 0.1406477	best: 0.1406477 (77)	total: 41.8s	remaining: 1m 58s
# 78:	learn: 0.1555291	test: 0.1405253	best: 0.1405253 (78)	total: 42.4s	remaining: 1m 58s
# 79:	learn: 0.1554076	test: 0.1404032	best: 0.1404032 (79)	total: 43s	remaining: 1m 58s
# 80:	learn: 0.1552848	test: 0.1403696	best: 0.1403696 (80)	total: 43.7s	remaining: 1m 58s
# 81:	learn: 0.1552626	test: 0.1403222	best: 0.1403222 (81)	total: 44.1s	remaining: 1m 57s
# 82:	learn: 0.1551986	test: 0.1403214	best: 0.1403214 (82)	total: 44.6s	remaining: 1m 56s
# 83:	learn: 0.1551833	test: 0.1402827	best: 0.1402827 (83)	total: 45s	remaining: 1m 55s
# 84:	learn: 0.1551649	test: 0.1402689	best: 0.1402689 (84)	total: 45.3s	remaining: 1m 54s
# 85:	learn: 0.1550615	test: 0.1401299	best: 0.1401299 (85)	total: 45.8s	remaining: 1m 53s
# 86:	learn: 0.1550128	test: 0.1401040	best: 0.1401040 (86)	total: 46.3s	remaining: 1m 53s
# 87:	learn: 0.1549873	test: 0.1401016	best: 0.1401016 (87)	total: 46.9s	remaining: 1m 52s
# 88:	learn: 0.1548902	test: 0.1400012	best: 0.1400012 (88)	total: 47.5s	remaining: 1m 52s
# 89:	learn: 0.1548521	test: 0.1399513	best: 0.1399513 (89)	total: 48s	remaining: 1m 51s
# 90:	learn: 0.1548063	test: 0.1398491	best: 0.1398491 (90)	total: 48.5s	remaining: 1m 51s
# 91:	learn: 0.1543599	test: 0.1396093	best: 0.1396093 (91)	total: 49.2s	remaining: 1m 51s
# 92:	learn: 0.1541429	test: 0.1395139	best: 0.1395139 (92)	total: 49.9s	remaining: 1m 50s
# 93:	learn: 0.1541366	test: 0.1394922	best: 0.1394922 (93)	total: 50.2s	remaining: 1m 49s
# 94:	learn: 0.1540829	test: 0.1395834	best: 0.1394922 (93)	total: 50.8s	remaining: 1m 49s
# 95:	learn: 0.1540722	test: 0.1395830	best: 0.1394922 (93)	total: 51.3s	remaining: 1m 48s
# 96:	learn: 0.1539365	test: 0.1394312	best: 0.1394312 (96)	total: 52s	remaining: 1m 48s
# 97:	learn: 0.1538693	test: 0.1393751	best: 0.1393751 (97)	total: 52.6s	remaining: 1m 48s
# 98:	learn: 0.1538645	test: 0.1393717	best: 0.1393717 (98)	total: 53.1s	remaining: 1m 47s
# 99:	learn: 0.1538125	test: 0.1393680	best: 0.1393680 (99)	total: 53.7s	remaining: 1m 47s
# 100:	learn: 0.1537946	test: 0.1393654	best: 0.1393654 (100)	total: 54s	remaining: 1m 46s
# 101:	learn: 0.1537216	test: 0.1394104	best: 0.1393654 (100)	total: 54.7s	remaining: 1m 46s
# 102:	learn: 0.1536306	test: 0.1394843	best: 0.1393654 (100)	total: 55.3s	remaining: 1m 45s
# 103:	learn: 0.1535787	test: 0.1394298	best: 0.1393654 (100)	total: 55.9s	remaining: 1m 45s
# 104:	learn: 0.1534417	test: 0.1393255	best: 0.1393255 (104)	total: 56.5s	remaining: 1m 44s
# 105:	learn: 0.1533026	test: 0.1392386	best: 0.1392386 (105)	total: 57.1s	remaining: 1m 44s
# 106:	learn: 0.1531777	test: 0.1391412	best: 0.1391412 (106)	total: 57.7s	remaining: 1m 44s
# 107:	learn: 0.1530814	test: 0.1391208	best: 0.1391208 (107)	total: 58.3s	remaining: 1m 43s
# 108:	learn: 0.1529419	test: 0.1391953	best: 0.1391208 (107)	total: 58.9s	remaining: 1m 43s
# 109:	learn: 0.1529306	test: 0.1391957	best: 0.1391208 (107)	total: 59.4s	remaining: 1m 42s
# 110:	learn: 0.1528774	test: 0.1392101	best: 0.1391208 (107)	total: 1m	remaining: 1m 42s
# 111:	learn: 0.1528087	test: 0.1392589	best: 0.1391208 (107)	total: 1m	remaining: 1m 41s
# 112:	learn: 0.1526570	test: 0.1391933	best: 0.1391208 (107)	total: 1m 1s	remaining: 1m 41s
# 113:	learn: 0.1526461	test: 0.1391941	best: 0.1391208 (107)	total: 1m 1s	remaining: 1m 40s
# 114:	learn: 0.1525870	test: 0.1391403	best: 0.1391208 (107)	total: 1m 2s	remaining: 1m 40s
# 115:	learn: 0.1525645	test: 0.1391131	best: 0.1391131 (115)	total: 1m 2s	remaining: 1m 39s
# 116:	learn: 0.1525037	test: 0.1391413	best: 0.1391131 (115)	total: 1m 3s	remaining: 1m 39s
# 117:	learn: 0.1524405	test: 0.1390947	best: 0.1390947 (117)	total: 1m 4s	remaining: 1m 39s
# 118:	learn: 0.1523623	test: 0.1390887	best: 0.1390887 (118)	total: 1m 4s	remaining: 1m 38s
# 119:	learn: 0.1522994	test: 0.1391247	best: 0.1390887 (118)	total: 1m 5s	remaining: 1m 38s
# 120:	learn: 0.1522632	test: 0.1391305	best: 0.1390887 (118)	total: 1m 6s	remaining: 1m 37s
# 121:	learn: 0.1522453	test: 0.1391199	best: 0.1390887 (118)	total: 1m 6s	remaining: 1m 37s
# 122:	learn: 0.1521991	test: 0.1390862	best: 0.1390862 (122)	total: 1m 7s	remaining: 1m 36s
# 123:	learn: 0.1521624	test: 0.1390870	best: 0.1390862 (122)	total: 1m 7s	remaining: 1m 36s
# 124:	learn: 0.1521174	test: 0.1391144	best: 0.1390862 (122)	total: 1m 8s	remaining: 1m 35s
# 125:	learn: 0.1520788	test: 0.1391804	best: 0.1390862 (122)	total: 1m 8s	remaining: 1m 35s
# 126:	learn: 0.1520576	test: 0.1391786	best: 0.1390862 (122)	total: 1m 9s	remaining: 1m 34s
# 127:	learn: 0.1520275	test: 0.1391708	best: 0.1390862 (122)	total: 1m 10s	remaining: 1m 34s
# 128:	learn: 0.1519262	test: 0.1391773	best: 0.1390862 (122)	total: 1m 10s	remaining: 1m 33s
# 129:	learn: 0.1519053	test: 0.1391532	best: 0.1390862 (122)	total: 1m 11s	remaining: 1m 33s
# 130:	learn: 0.1518750	test: 0.1391747	best: 0.1390862 (122)	total: 1m 11s	remaining: 1m 32s
# 131:	learn: 0.1518520	test: 0.1391871	best: 0.1390862 (122)	total: 1m 12s	remaining: 1m 32s
# 132:	learn: 0.1518377	test: 0.1392148	best: 0.1390862 (122)	total: 1m 13s	remaining: 1m 31s
# 133:	learn: 0.1518140	test: 0.1392159	best: 0.1390862 (122)	total: 1m 13s	remaining: 1m 31s
# 134:	learn: 0.1517165	test: 0.1390811	best: 0.1390811 (134)	total: 1m 14s	remaining: 1m 31s
# 135:	learn: 0.1516992	test: 0.1391044	best: 0.1390811 (134)	total: 1m 15s	remaining: 1m 30s
# 136:	learn: 0.1515306	test: 0.1390626	best: 0.1390626 (136)	total: 1m 15s	remaining: 1m 30s
# 137:	learn: 0.1515173	test: 0.1390707	best: 0.1390626 (136)	total: 1m 16s	remaining: 1m 29s
# 138:	learn: 0.1514379	test: 0.1390373	best: 0.1390373 (138)	total: 1m 17s	remaining: 1m 29s
# 139:	learn: 0.1513508	test: 0.1390378	best: 0.1390373 (138)	total: 1m 17s	remaining: 1m 28s
# 140:	learn: 0.1512949	test: 0.1389577	best: 0.1389577 (140)	total: 1m 18s	remaining: 1m 28s
# 141:	learn: 0.1512578	test: 0.1389113	best: 0.1389113 (141)	total: 1m 18s	remaining: 1m 27s
# 142:	learn: 0.1511359	test: 0.1389010	best: 0.1389010 (142)	total: 1m 19s	remaining: 1m 27s
# 143:	learn: 0.1510820	test: 0.1389220	best: 0.1389010 (142)	total: 1m 20s	remaining: 1m 26s
# 144:	learn: 0.1510107	test: 0.1389371	best: 0.1389010 (142)	total: 1m 20s	remaining: 1m 26s
# 145:	learn: 0.1509925	test: 0.1389283	best: 0.1389010 (142)	total: 1m 21s	remaining: 1m 25s
# 146:	learn: 0.1508623	test: 0.1389634	best: 0.1389010 (142)	total: 1m 22s	remaining: 1m 25s
# 147:	learn: 0.1508165	test: 0.1389334	best: 0.1389010 (142)	total: 1m 22s	remaining: 1m 24s
# 148:	learn: 0.1507943	test: 0.1389385	best: 0.1389010 (142)	total: 1m 23s	remaining: 1m 24s
# 149:	learn: 0.1507671	test: 0.1389550	best: 0.1389010 (142)	total: 1m 23s	remaining: 1m 23s
# 150:	learn: 0.1505296	test: 0.1388143	best: 0.1388143 (150)	total: 1m 24s	remaining: 1m 23s
# 151:	learn: 0.1505250	test: 0.1388158	best: 0.1388143 (150)	total: 1m 25s	remaining: 1m 22s
# 152:	learn: 0.1503841	test: 0.1387050	best: 0.1387050 (152)	total: 1m 25s	remaining: 1m 22s
# 153:	learn: 0.1503635	test: 0.1386912	best: 0.1386912 (153)	total: 1m 26s	remaining: 1m 22s
# 154:	learn: 0.1501967	test: 0.1386603	best: 0.1386603 (154)	total: 1m 27s	remaining: 1m 21s
# 155:	learn: 0.1501899	test: 0.1386548	best: 0.1386548 (155)	total: 1m 27s	remaining: 1m 21s
# 156:	learn: 0.1501559	test: 0.1386839	best: 0.1386548 (155)	total: 1m 28s	remaining: 1m 20s
# 157:	learn: 0.1501543	test: 0.1386915	best: 0.1386548 (155)	total: 1m 29s	remaining: 1m 20s
# 158:	learn: 0.1501422	test: 0.1386587	best: 0.1386548 (155)	total: 1m 29s	remaining: 1m 19s
# 159:	learn: 0.1501234	test: 0.1386072	best: 0.1386072 (159)	total: 1m 30s	remaining: 1m 18s
# 160:	learn: 0.1500392	test: 0.1385545	best: 0.1385545 (160)	total: 1m 30s	remaining: 1m 18s
# 161:	learn: 0.1500202	test: 0.1385459	best: 0.1385459 (161)	total: 1m 31s	remaining: 1m 17s
# 162:	learn: 0.1499542	test: 0.1385473	best: 0.1385459 (161)	total: 1m 32s	remaining: 1m 17s
# 163:	learn: 0.1498537	test: 0.1385709	best: 0.1385459 (161)	total: 1m 32s	remaining: 1m 16s
# 164:	learn: 0.1498234	test: 0.1385509	best: 0.1385459 (161)	total: 1m 33s	remaining: 1m 16s
# 165:	learn: 0.1496384	test: 0.1385165	best: 0.1385165 (165)	total: 1m 34s	remaining: 1m 15s
# 166:	learn: 0.1496056	test: 0.1385331	best: 0.1385165 (165)	total: 1m 34s	remaining: 1m 15s
# 167:	learn: 0.1495661	test: 0.1385722	best: 0.1385165 (165)	total: 1m 35s	remaining: 1m 14s
# 168:	learn: 0.1494142	test: 0.1385226	best: 0.1385165 (165)	total: 1m 36s	remaining: 1m 14s
# 169:	learn: 0.1493517	test: 0.1384758	best: 0.1384758 (169)	total: 1m 36s	remaining: 1m 13s
# 170:	learn: 0.1493420	test: 0.1384886	best: 0.1384758 (169)	total: 1m 37s	remaining: 1m 13s
# 171:	learn: 0.1492740	test: 0.1385179	best: 0.1384758 (169)	total: 1m 37s	remaining: 1m 12s
# 172:	learn: 0.1492161	test: 0.1385225	best: 0.1384758 (169)	total: 1m 38s	remaining: 1m 12s
# 173:	learn: 0.1491698	test: 0.1385414	best: 0.1384758 (169)	total: 1m 39s	remaining: 1m 11s
# 174:	learn: 0.1490943	test: 0.1384886	best: 0.1384758 (169)	total: 1m 39s	remaining: 1m 11s
# 175:	learn: 0.1490413	test: 0.1384810	best: 0.1384758 (169)	total: 1m 40s	remaining: 1m 10s
# 176:	learn: 0.1489828	test: 0.1384839	best: 0.1384758 (169)	total: 1m 41s	remaining: 1m 10s
# 177:	learn: 0.1489594	test: 0.1385186	best: 0.1384758 (169)	total: 1m 41s	remaining: 1m 9s
# 178:	learn: 0.1489078	test: 0.1385139	best: 0.1384758 (169)	total: 1m 42s	remaining: 1m 9s
# 179:	learn: 0.1488331	test: 0.1384214	best: 0.1384214 (179)	total: 1m 43s	remaining: 1m 8s
# 180:	learn: 0.1487657	test: 0.1385120	best: 0.1384214 (179)	total: 1m 43s	remaining: 1m 8s
# 181:	learn: 0.1487574	test: 0.1385201	best: 0.1384214 (179)	total: 1m 44s	remaining: 1m 7s
# 182:	learn: 0.1487546	test: 0.1385280	best: 0.1384214 (179)	total: 1m 44s	remaining: 1m 7s
# 183:	learn: 0.1487431	test: 0.1385291	best: 0.1384214 (179)	total: 1m 45s	remaining: 1m 6s
# 184:	learn: 0.1486910	test: 0.1384800	best: 0.1384214 (179)	total: 1m 46s	remaining: 1m 5s
# 185:	learn: 0.1486507	test: 0.1384820	best: 0.1384214 (179)	total: 1m 46s	remaining: 1m 5s
# 186:	learn: 0.1485546	test: 0.1384537	best: 0.1384214 (179)	total: 1m 47s	remaining: 1m 4s
# 187:	learn: 0.1484225	test: 0.1384495	best: 0.1384214 (179)	total: 1m 48s	remaining: 1m 4s
# 188:	learn: 0.1484044	test: 0.1384526	best: 0.1384214 (179)	total: 1m 48s	remaining: 1m 3s
# 189:	learn: 0.1484006	test: 0.1384555	best: 0.1384214 (179)	total: 1m 49s	remaining: 1m 3s
# 190:	learn: 0.1483783	test: 0.1384596	best: 0.1384214 (179)	total: 1m 49s	remaining: 1m 2s
# 191:	learn: 0.1483420	test: 0.1383990	best: 0.1383990 (191)	total: 1m 50s	remaining: 1m 2s
# 192:	learn: 0.1482758	test: 0.1384334	best: 0.1383990 (191)	total: 1m 51s	remaining: 1m 1s
# 193:	learn: 0.1482527	test: 0.1384615	best: 0.1383990 (191)	total: 1m 51s	remaining: 1m 1s
# 194:	learn: 0.1482431	test: 0.1384171	best: 0.1383990 (191)	total: 1m 52s	remaining: 1m
# 195:	learn: 0.1482290	test: 0.1384108	best: 0.1383990 (191)	total: 1m 53s	remaining: 1m
# 196:	learn: 0.1481406	test: 0.1384295	best: 0.1383990 (191)	total: 1m 53s	remaining: 59.5s
# 197:	learn: 0.1481399	test: 0.1384283	best: 0.1383990 (191)	total: 1m 54s	remaining: 58.9s
# 198:	learn: 0.1481321	test: 0.1384241	best: 0.1383990 (191)	total: 1m 54s	remaining: 58.3s
# 199:	learn: 0.1481308	test: 0.1384298	best: 0.1383990 (191)	total: 1m 55s	remaining: 57.8s
# 200:	learn: 0.1481164	test: 0.1384379	best: 0.1383990 (191)	total: 1m 56s	remaining: 57.2s
# 201:	learn: 0.1480824	test: 0.1384520	best: 0.1383990 (191)	total: 1m 56s	remaining: 56.6s
# 202:	learn: 0.1480232	test: 0.1383804	best: 0.1383804 (202)	total: 1m 57s	remaining: 56.1s
# 203:	learn: 0.1480180	test: 0.1383765	best: 0.1383765 (203)	total: 1m 58s	remaining: 55.5s
# 204:	learn: 0.1480096	test: 0.1383929	best: 0.1383765 (203)	total: 1m 58s	remaining: 55.1s
# 205:	learn: 0.1480060	test: 0.1383971	best: 0.1383765 (203)	total: 1m 59s	remaining: 54.5s
# 206:	learn: 0.1479713	test: 0.1384153	best: 0.1383765 (203)	total: 2m	remaining: 54s
# 207:	learn: 0.1479650	test: 0.1384136	best: 0.1383765 (203)	total: 2m	remaining: 53.4s
# 208:	learn: 0.1479340	test: 0.1383646	best: 0.1383646 (208)	total: 2m 1s	remaining: 52.9s
# 209:	learn: 0.1478678	test: 0.1383554	best: 0.1383554 (209)	total: 2m 2s	remaining: 52.3s
# 210:	learn: 0.1478473	test: 0.1383618	best: 0.1383554 (209)	total: 2m 2s	remaining: 51.8s
# 211:	learn: 0.1477954	test: 0.1384190	best: 0.1383554 (209)	total: 2m 3s	remaining: 51.2s
# 212:	learn: 0.1477729	test: 0.1384342	best: 0.1383554 (209)	total: 2m 4s	remaining: 50.7s
# 213:	learn: 0.1477698	test: 0.1384587	best: 0.1383554 (209)	total: 2m 4s	remaining: 50s
# 214:	learn: 0.1477435	test: 0.1384526	best: 0.1383554 (209)	total: 2m 5s	remaining: 49.5s
# 215:	learn: 0.1477361	test: 0.1384465	best: 0.1383554 (209)	total: 2m 5s	remaining: 48.9s
# 216:	learn: 0.1477014	test: 0.1384053	best: 0.1383554 (209)	total: 2m 6s	remaining: 48.4s
# 217:	learn: 0.1476943	test: 0.1384118	best: 0.1383554 (209)	total: 2m 7s	remaining: 47.8s
# 218:	learn: 0.1476859	test: 0.1383890	best: 0.1383554 (209)	total: 2m 7s	remaining: 47.2s
# 219:	learn: 0.1476509	test: 0.1383882	best: 0.1383554 (209)	total: 2m 8s	remaining: 46.7s
# 220:	learn: 0.1476299	test: 0.1384073	best: 0.1383554 (209)	total: 2m 8s	remaining: 46.1s
# 221:	learn: 0.1476288	test: 0.1384114	best: 0.1383554 (209)	total: 2m 9s	remaining: 45.5s
# 222:	learn: 0.1476269	test: 0.1384126	best: 0.1383554 (209)	total: 2m 10s	remaining: 45s
# 223:	learn: 0.1476012	test: 0.1383902	best: 0.1383554 (209)	total: 2m 10s	remaining: 44.4s
# 224:	learn: 0.1475985	test: 0.1383919	best: 0.1383554 (209)	total: 2m 11s	remaining: 43.8s
# 225:	learn: 0.1475565	test: 0.1383807	best: 0.1383554 (209)	total: 2m 12s	remaining: 43.2s
# 226:	learn: 0.1475241	test: 0.1384001	best: 0.1383554 (209)	total: 2m 12s	remaining: 42.6s
# 227:	learn: 0.1475086	test: 0.1384063	best: 0.1383554 (209)	total: 2m 13s	remaining: 42.1s
# 228:	learn: 0.1475066	test: 0.1384055	best: 0.1383554 (209)	total: 2m 13s	remaining: 41.5s
# 229:	learn: 0.1474497	test: 0.1384393	best: 0.1383554 (209)	total: 2m 14s	remaining: 40.9s
# 230:	learn: 0.1474456	test: 0.1384327	best: 0.1383554 (209)	total: 2m 15s	remaining: 40.3s
# 231:	learn: 0.1473466	test: 0.1383748	best: 0.1383554 (209)	total: 2m 15s	remaining: 39.8s
# 232:	learn: 0.1473358	test: 0.1383663	best: 0.1383554 (209)	total: 2m 16s	remaining: 39.2s
# 233:	learn: 0.1472673	test: 0.1384630	best: 0.1383554 (209)	total: 2m 16s	remaining: 38.6s
# 234:	learn: 0.1472262	test: 0.1384624	best: 0.1383554 (209)	total: 2m 17s	remaining: 38s
# 235:	learn: 0.1472069	test: 0.1384819	best: 0.1383554 (209)	total: 2m 18s	remaining: 37.4s
# 236:	learn: 0.1471563	test: 0.1384322	best: 0.1383554 (209)	total: 2m 18s	remaining: 36.8s
# 237:	learn: 0.1470539	test: 0.1383481	best: 0.1383481 (237)	total: 2m 19s	remaining: 36.3s
# 238:	learn: 0.1470423	test: 0.1383370	best: 0.1383370 (238)	total: 2m 19s	remaining: 35.7s
# 239:	learn: 0.1470187	test: 0.1383491	best: 0.1383370 (238)	total: 2m 20s	remaining: 35.1s
# 240:	learn: 0.1470151	test: 0.1383487	best: 0.1383370 (238)	total: 2m 21s	remaining: 34.5s
# 241:	learn: 0.1469336	test: 0.1382996	best: 0.1382996 (241)	total: 2m 21s	remaining: 34s
# 242:	learn: 0.1469243	test: 0.1383285	best: 0.1382996 (241)	total: 2m 22s	remaining: 33.4s
# 243:	learn: 0.1468898	test: 0.1383494	best: 0.1382996 (241)	total: 2m 23s	remaining: 32.8s
# 244:	learn: 0.1468414	test: 0.1383601	best: 0.1382996 (241)	total: 2m 23s	remaining: 32.3s
# 245:	learn: 0.1467870	test: 0.1383190	best: 0.1382996 (241)	total: 2m 24s	remaining: 31.7s
# 246:	learn: 0.1467088	test: 0.1382865	best: 0.1382865 (246)	total: 2m 24s	remaining: 31.1s
# 247:	learn: 0.1466646	test: 0.1383053	best: 0.1382865 (246)	total: 2m 25s	remaining: 30.5s
# 248:	learn: 0.1466363	test: 0.1383451	best: 0.1382865 (246)	total: 2m 26s	remaining: 30s
# 249:	learn: 0.1465958	test: 0.1383215	best: 0.1382865 (246)	total: 2m 27s	remaining: 29.4s
# 250:	learn: 0.1465956	test: 0.1383216	best: 0.1382865 (246)	total: 2m 27s	remaining: 28.8s
# 251:	learn: 0.1465860	test: 0.1383170	best: 0.1382865 (246)	total: 2m 28s	remaining: 28.2s
# 252:	learn: 0.1465757	test: 0.1383242	best: 0.1382865 (246)	total: 2m 28s	remaining: 27.6s
# 253:	learn: 0.1465579	test: 0.1383098	best: 0.1382865 (246)	total: 2m 29s	remaining: 27.1s
# 254:	learn: 0.1464475	test: 0.1382578	best: 0.1382578 (254)	total: 2m 30s	remaining: 26.5s
# 255:	learn: 0.1464289	test: 0.1382613	best: 0.1382578 (254)	total: 2m 30s	remaining: 25.9s
# 256:	learn: 0.1463757	test: 0.1382483	best: 0.1382483 (256)	total: 2m 31s	remaining: 25.3s
# 257:	learn: 0.1463722	test: 0.1382564	best: 0.1382483 (256)	total: 2m 32s	remaining: 24.7s
# 258:	learn: 0.1463535	test: 0.1382827	best: 0.1382483 (256)	total: 2m 32s	remaining: 24.2s
# 259:	learn: 0.1463209	test: 0.1383055	best: 0.1382483 (256)	total: 2m 33s	remaining: 23.6s
# 260:	learn: 0.1463209	test: 0.1383056	best: 0.1382483 (256)	total: 2m 33s	remaining: 22.9s
# 261:	learn: 0.1463123	test: 0.1383231	best: 0.1382483 (256)	total: 2m 34s	remaining: 22.4s
# 262:	learn: 0.1462981	test: 0.1383410	best: 0.1382483 (256)	total: 2m 34s	remaining: 21.8s
# 263:	learn: 0.1462889	test: 0.1383353	best: 0.1382483 (256)	total: 2m 35s	remaining: 21.2s
# 264:	learn: 0.1462875	test: 0.1383323	best: 0.1382483 (256)	total: 2m 36s	remaining: 20.6s
# 265:	learn: 0.1462721	test: 0.1383379	best: 0.1382483 (256)	total: 2m 36s	remaining: 20s
# 266:	learn: 0.1462641	test: 0.1383371	best: 0.1382483 (256)	total: 2m 37s	remaining: 19.4s
# 267:	learn: 0.1462292	test: 0.1383570	best: 0.1382483 (256)	total: 2m 37s	remaining: 18.8s
# 268:	learn: 0.1462172	test: 0.1383698	best: 0.1382483 (256)	total: 2m 38s	remaining: 18.3s
# 269:	learn: 0.1462155	test: 0.1383582	best: 0.1382483 (256)	total: 2m 38s	remaining: 17.7s
# 270:	learn: 0.1462080	test: 0.1383633	best: 0.1382483 (256)	total: 2m 39s	remaining: 17.1s
# 271:	learn: 0.1461651	test: 0.1383331	best: 0.1382483 (256)	total: 2m 40s	remaining: 16.5s
# 272:	learn: 0.1459665	test: 0.1383449	best: 0.1382483 (256)	total: 2m 40s	remaining: 15.9s
# 273:	learn: 0.1458948	test: 0.1383230	best: 0.1382483 (256)	total: 2m 41s	remaining: 15.3s
# 274:	learn: 0.1458793	test: 0.1383434	best: 0.1382483 (256)	total: 2m 42s	remaining: 14.7s
# 275:	learn: 0.1458125	test: 0.1383178	best: 0.1382483 (256)	total: 2m 42s	remaining: 14.2s
# 276:	learn: 0.1457931	test: 0.1383336	best: 0.1382483 (256)	total: 2m 43s	remaining: 13.6s
# 277:	learn: 0.1457568	test: 0.1383283	best: 0.1382483 (256)	total: 2m 43s	remaining: 13s
# 278:	learn: 0.1456908	test: 0.1383490	best: 0.1382483 (256)	total: 2m 44s	remaining: 12.4s
# 279:	learn: 0.1456427	test: 0.1383413	best: 0.1382483 (256)	total: 2m 45s	remaining: 11.8s
# 280:	learn: 0.1456171	test: 0.1383227	best: 0.1382483 (256)	total: 2m 45s	remaining: 11.2s
# 281:	learn: 0.1456135	test: 0.1383191	best: 0.1382483 (256)	total: 2m 46s	remaining: 10.6s
# 282:	learn: 0.1455965	test: 0.1383721	best: 0.1382483 (256)	total: 2m 46s	remaining: 10s
# 283:	learn: 0.1455623	test: 0.1384312	best: 0.1382483 (256)	total: 2m 47s	remaining: 9.43s
# 284:	learn: 0.1455389	test: 0.1384692	best: 0.1382483 (256)	total: 2m 47s	remaining: 8.84s
# 285:	learn: 0.1455249	test: 0.1384801	best: 0.1382483 (256)	total: 2m 48s	remaining: 8.25s
# 286:	learn: 0.1455163	test: 0.1384766	best: 0.1382483 (256)	total: 2m 49s	remaining: 7.66s
# 287:	learn: 0.1454867	test: 0.1384791	best: 0.1382483 (256)	total: 2m 49s	remaining: 7.07s
# 288:	learn: 0.1454767	test: 0.1384842	best: 0.1382483 (256)	total: 2m 50s	remaining: 6.49s
# 289:	learn: 0.1454701	test: 0.1384704	best: 0.1382483 (256)	total: 2m 50s	remaining: 5.9s
# 290:	learn: 0.1454365	test: 0.1385055	best: 0.1382483 (256)	total: 2m 51s	remaining: 5.31s
# 291:	learn: 0.1454331	test: 0.1384914	best: 0.1382483 (256)	total: 2m 52s	remaining: 4.72s
# 292:	learn: 0.1454170	test: 0.1385024	best: 0.1382483 (256)	total: 2m 52s	remaining: 4.13s
# 293:	learn: 0.1454075	test: 0.1384778	best: 0.1382483 (256)	total: 2m 53s	remaining: 3.54s
# 294:	learn: 0.1453801	test: 0.1384931	best: 0.1382483 (256)	total: 2m 53s	remaining: 2.95s
# 295:	learn: 0.1453268	test: 0.1384573	best: 0.1382483 (256)	total: 2m 54s	remaining: 2.36s
# 296:	learn: 0.1453081	test: 0.1384741	best: 0.1382483 (256)	total: 2m 55s	remaining: 1.77s
# 297:	learn: 0.1452762	test: 0.1385395	best: 0.1382483 (256)	total: 2m 55s	remaining: 1.18s
# 298:	learn: 0.1451014	test: 0.1386094	best: 0.1382483 (256)	total: 2m 56s	remaining: 590ms
# 299:	learn: 0.1450996	test: 0.1386158	best: 0.1382483 (256)	total: 2m 57s	remaining: 0us
#
# bestTest = 0.1382483022
# bestIteration = 256
#
# Shrink model to first 257 iterations.
# 0:	learn: 0.5779917	test: 0.5777233	best: 0.5777233 (0)	total: 394ms	remaining: 1m 57s
# 1:	learn: 0.4918309	test: 0.4923643	best: 0.4923643 (1)	total: 695ms	remaining: 1m 43s
# 2:	learn: 0.4269347	test: 0.4281818	best: 0.4281818 (2)	total: 896ms	remaining: 1m 28s
# 3:	learn: 0.3719129	test: 0.3724868	best: 0.3724868 (3)	total: 1.49s	remaining: 1m 50s
# 4:	learn: 0.3359711	test: 0.3372246	best: 0.3372246 (4)	total: 1.7s	remaining: 1m 40s
# 5:	learn: 0.3044141	test: 0.3041539	best: 0.3041539 (5)	total: 2.2s	remaining: 1m 47s
# 6:	learn: 0.2842647	test: 0.2847810	best: 0.2847810 (6)	total: 2.49s	remaining: 1m 44s
# 7:	learn: 0.2631033	test: 0.2634623	best: 0.2634623 (7)	total: 2.99s	remaining: 1m 49s
# 8:	learn: 0.2468169	test: 0.2465705	best: 0.2465705 (8)	total: 3.5s	remaining: 1m 53s
# 9:	learn: 0.2337055	test: 0.2330156	best: 0.2330156 (9)	total: 4.09s	remaining: 1m 58s
# 10:	learn: 0.2235804	test: 0.2222434	best: 0.2222434 (10)	total: 4.69s	remaining: 2m 3s
# 11:	learn: 0.2130543	test: 0.2102737	best: 0.2102737 (11)	total: 5.3s	remaining: 2m 7s
# 12:	learn: 0.2056818	test: 0.2019742	best: 0.2019742 (12)	total: 5.79s	remaining: 2m 7s
# 13:	learn: 0.1996499	test: 0.1947888	best: 0.1947888 (13)	total: 6.2s	remaining: 2m 6s
# 14:	learn: 0.1945072	test: 0.1886140	best: 0.1886140 (14)	total: 6.7s	remaining: 2m 7s
# 15:	learn: 0.1899886	test: 0.1826617	best: 0.1826617 (15)	total: 7.29s	remaining: 2m 9s
# 16:	learn: 0.1863694	test: 0.1784039	best: 0.1784039 (16)	total: 7.89s	remaining: 2m 11s
# 17:	learn: 0.1840102	test: 0.1753960	best: 0.1753960 (17)	total: 8.29s	remaining: 2m 9s
# 18:	learn: 0.1820297	test: 0.1729372	best: 0.1729372 (18)	total: 8.79s	remaining: 2m 10s
# 19:	learn: 0.1799612	test: 0.1701274	best: 0.1701274 (19)	total: 9.39s	remaining: 2m 11s
# 20:	learn: 0.1787986	test: 0.1685310	best: 0.1685310 (20)	total: 9.79s	remaining: 2m 10s
# 21:	learn: 0.1772067	test: 0.1664256	best: 0.1664256 (21)	total: 10.4s	remaining: 2m 11s
# 22:	learn: 0.1760504	test: 0.1646667	best: 0.1646667 (22)	total: 11s	remaining: 2m 12s
# 23:	learn: 0.1751257	test: 0.1632790	best: 0.1632790 (23)	total: 11.4s	remaining: 2m 10s
# 24:	learn: 0.1745330	test: 0.1624437	best: 0.1624437 (24)	total: 11.9s	remaining: 2m 10s
# 25:	learn: 0.1741949	test: 0.1618910	best: 0.1618910 (25)	total: 12.2s	remaining: 2m 8s
# 26:	learn: 0.1729866	test: 0.1602473	best: 0.1602473 (26)	total: 12.8s	remaining: 2m 9s
# 27:	learn: 0.1723280	test: 0.1592115	best: 0.1592115 (27)	total: 13.5s	remaining: 2m 11s
# 28:	learn: 0.1717369	test: 0.1586367	best: 0.1586367 (28)	total: 13.9s	remaining: 2m 9s
# 29:	learn: 0.1710437	test: 0.1576529	best: 0.1576529 (29)	total: 14.4s	remaining: 2m 9s
# 30:	learn: 0.1703478	test: 0.1569540	best: 0.1569540 (30)	total: 15.1s	remaining: 2m 10s
# 31:	learn: 0.1700052	test: 0.1565980	best: 0.1565980 (31)	total: 15.4s	remaining: 2m 8s
# 32:	learn: 0.1692374	test: 0.1555192	best: 0.1555192 (32)	total: 16.1s	remaining: 2m 10s
# 33:	learn: 0.1682730	test: 0.1544270	best: 0.1544270 (33)	total: 16.6s	remaining: 2m 9s
# 34:	learn: 0.1678554	test: 0.1538559	best: 0.1538559 (34)	total: 17.2s	remaining: 2m 10s
# 35:	learn: 0.1675475	test: 0.1535153	best: 0.1535153 (35)	total: 17.8s	remaining: 2m 10s
# 36:	learn: 0.1663782	test: 0.1520709	best: 0.1520709 (36)	total: 18.5s	remaining: 2m 11s
# 37:	learn: 0.1654659	test: 0.1509563	best: 0.1509563 (37)	total: 19.1s	remaining: 2m 11s
# 38:	learn: 0.1648141	test: 0.1501665	best: 0.1501665 (38)	total: 19.7s	remaining: 2m 11s
# 39:	learn: 0.1639304	test: 0.1491256	best: 0.1491256 (39)	total: 20.4s	remaining: 2m 12s
# 40:	learn: 0.1633689	test: 0.1484570	best: 0.1484570 (40)	total: 21.1s	remaining: 2m 13s
# 41:	learn: 0.1629932	test: 0.1480457	best: 0.1480457 (41)	total: 21.8s	remaining: 2m 13s
# 42:	learn: 0.1629863	test: 0.1480042	best: 0.1480042 (42)	total: 22.1s	remaining: 2m 11s
# 43:	learn: 0.1629736	test: 0.1479675	best: 0.1479675 (43)	total: 22.4s	remaining: 2m 10s
# 44:	learn: 0.1629573	test: 0.1479484	best: 0.1479484 (44)	total: 22.8s	remaining: 2m 9s
# 45:	learn: 0.1626290	test: 0.1475012	best: 0.1475012 (45)	total: 23.4s	remaining: 2m 9s
# 46:	learn: 0.1621369	test: 0.1468471	best: 0.1468471 (46)	total: 24s	remaining: 2m 9s
# 47:	learn: 0.1619219	test: 0.1465149	best: 0.1465149 (47)	total: 24.6s	remaining: 2m 9s
# 48:	learn: 0.1616146	test: 0.1464054	best: 0.1464054 (48)	total: 25.3s	remaining: 2m 9s
# 49:	learn: 0.1608106	test: 0.1456050	best: 0.1456050 (49)	total: 26s	remaining: 2m 9s
# 50:	learn: 0.1607318	test: 0.1455327	best: 0.1455327 (50)	total: 26.4s	remaining: 2m 8s
# 51:	learn: 0.1607295	test: 0.1455362	best: 0.1455327 (50)	total: 26.7s	remaining: 2m 7s
# 52:	learn: 0.1602285	test: 0.1449704	best: 0.1449704 (52)	total: 27.4s	remaining: 2m 7s
# 53:	learn: 0.1596262	test: 0.1442710	best: 0.1442710 (53)	total: 28s	remaining: 2m 7s
# 54:	learn: 0.1589262	test: 0.1436719	best: 0.1436719 (54)	total: 28.7s	remaining: 2m 7s
# 55:	learn: 0.1588952	test: 0.1436394	best: 0.1436394 (55)	total: 29.1s	remaining: 2m 6s
# 56:	learn: 0.1587825	test: 0.1435504	best: 0.1435504 (56)	total: 29.8s	remaining: 2m 6s
# 57:	learn: 0.1587231	test: 0.1434930	best: 0.1434930 (57)	total: 30.2s	remaining: 2m 5s
# 58:	learn: 0.1583138	test: 0.1432153	best: 0.1432153 (58)	total: 30.7s	remaining: 2m 5s
# 59:	learn: 0.1582902	test: 0.1431829	best: 0.1431829 (59)	total: 31.1s	remaining: 2m 4s
# 60:	learn: 0.1582555	test: 0.1431532	best: 0.1431532 (60)	total: 31.5s	remaining: 2m 3s
# 61:	learn: 0.1582170	test: 0.1430810	best: 0.1430810 (61)	total: 32s	remaining: 2m 2s
# 62:	learn: 0.1582083	test: 0.1430782	best: 0.1430782 (62)	total: 32.4s	remaining: 2m 1s
# 63:	learn: 0.1581184	test: 0.1430848	best: 0.1430782 (62)	total: 32.7s	remaining: 2m
# 64:	learn: 0.1576850	test: 0.1426702	best: 0.1426702 (64)	total: 33.3s	remaining: 2m
# 65:	learn: 0.1576661	test: 0.1426228	best: 0.1426228 (65)	total: 33.8s	remaining: 1m 59s
# 66:	learn: 0.1574984	test: 0.1425654	best: 0.1425654 (66)	total: 34.4s	remaining: 1m 59s
# 67:	learn: 0.1574803	test: 0.1425441	best: 0.1425441 (67)	total: 34.8s	remaining: 1m 58s
# 68:	learn: 0.1573752	test: 0.1423465	best: 0.1423465 (68)	total: 35.4s	remaining: 1m 58s
# 69:	learn: 0.1573577	test: 0.1423173	best: 0.1423173 (69)	total: 35.8s	remaining: 1m 57s
# 70:	learn: 0.1571749	test: 0.1422351	best: 0.1422351 (70)	total: 36.5s	remaining: 1m 57s
# 71:	learn: 0.1566951	test: 0.1418485	best: 0.1418485 (71)	total: 37.1s	remaining: 1m 57s
# 72:	learn: 0.1565615	test: 0.1417772	best: 0.1417772 (72)	total: 37.7s	remaining: 1m 57s
# 73:	learn: 0.1565196	test: 0.1417656	best: 0.1417656 (73)	total: 38.1s	remaining: 1m 56s
# 74:	learn: 0.1564966	test: 0.1417668	best: 0.1417656 (73)	total: 38.4s	remaining: 1m 55s
# 75:	learn: 0.1564283	test: 0.1416956	best: 0.1416956 (75)	total: 39s	remaining: 1m 54s
# 76:	learn: 0.1563952	test: 0.1417217	best: 0.1416956 (75)	total: 39.4s	remaining: 1m 54s
# 77:	learn: 0.1563219	test: 0.1417410	best: 0.1416956 (75)	total: 40.1s	remaining: 1m 54s
# 78:	learn: 0.1562771	test: 0.1417695	best: 0.1416956 (75)	total: 40.6s	remaining: 1m 53s
# 79:	learn: 0.1562365	test: 0.1417464	best: 0.1416956 (75)	total: 41.2s	remaining: 1m 53s
# 80:	learn: 0.1561850	test: 0.1417294	best: 0.1416956 (75)	total: 41.7s	remaining: 1m 52s
# 81:	learn: 0.1561140	test: 0.1417112	best: 0.1416956 (75)	total: 42.2s	remaining: 1m 52s
# 82:	learn: 0.1559913	test: 0.1415503	best: 0.1415503 (82)	total: 42.8s	remaining: 1m 51s
# 83:	learn: 0.1559715	test: 0.1415234	best: 0.1415234 (83)	total: 43.2s	remaining: 1m 51s
# 84:	learn: 0.1559516	test: 0.1415145	best: 0.1415145 (84)	total: 43.6s	remaining: 1m 50s
# 85:	learn: 0.1558022	test: 0.1414094	best: 0.1414094 (85)	total: 44.2s	remaining: 1m 49s
# 86:	learn: 0.1558018	test: 0.1414089	best: 0.1414089 (86)	total: 44.5s	remaining: 1m 48s
# 87:	learn: 0.1556757	test: 0.1413664	best: 0.1413664 (87)	total: 45.1s	remaining: 1m 48s
# 88:	learn: 0.1556482	test: 0.1413799	best: 0.1413664 (87)	total: 45.7s	remaining: 1m 48s
# 89:	learn: 0.1555994	test: 0.1413736	best: 0.1413664 (87)	total: 46.3s	remaining: 1m 47s
# 90:	learn: 0.1555873	test: 0.1413555	best: 0.1413555 (90)	total: 46.7s	remaining: 1m 47s
# 91:	learn: 0.1555188	test: 0.1413656	best: 0.1413555 (90)	total: 47s	remaining: 1m 46s
# 92:	learn: 0.1552718	test: 0.1411360	best: 0.1411360 (92)	total: 47.7s	remaining: 1m 46s
# 93:	learn: 0.1551943	test: 0.1411191	best: 0.1411191 (93)	total: 48.2s	remaining: 1m 45s
# 94:	learn: 0.1550726	test: 0.1410430	best: 0.1410430 (94)	total: 48.9s	remaining: 1m 45s
# 95:	learn: 0.1548525	test: 0.1409544	best: 0.1409544 (95)	total: 49.5s	remaining: 1m 45s
# 96:	learn: 0.1548431	test: 0.1409497	best: 0.1409497 (96)	total: 50s	remaining: 1m 44s
# 97:	learn: 0.1548107	test: 0.1409529	best: 0.1409497 (96)	total: 50.6s	remaining: 1m 44s
# 98:	learn: 0.1547590	test: 0.1409338	best: 0.1409338 (98)	total: 51s	remaining: 1m 43s
# 99:	learn: 0.1547404	test: 0.1409149	best: 0.1409149 (99)	total: 51.6s	remaining: 1m 43s
# 100:	learn: 0.1546875	test: 0.1408928	best: 0.1408928 (100)	total: 52.3s	remaining: 1m 42s
# 101:	learn: 0.1546283	test: 0.1408904	best: 0.1408904 (101)	total: 52.8s	remaining: 1m 42s
# 102:	learn: 0.1545043	test: 0.1409062	best: 0.1408904 (101)	total: 53.5s	remaining: 1m 42s
# 103:	learn: 0.1544916	test: 0.1409146	best: 0.1408904 (101)	total: 54s	remaining: 1m 41s
# 104:	learn: 0.1544735	test: 0.1409038	best: 0.1408904 (101)	total: 54.6s	remaining: 1m 41s
# 105:	learn: 0.1544011	test: 0.1408791	best: 0.1408791 (105)	total: 55.2s	remaining: 1m 40s
# 106:	learn: 0.1542554	test: 0.1408273	best: 0.1408273 (106)	total: 55.8s	remaining: 1m 40s
# 107:	learn: 0.1541603	test: 0.1407354	best: 0.1407354 (107)	total: 56.3s	remaining: 1m 40s
# 108:	learn: 0.1541230	test: 0.1406824	best: 0.1406824 (108)	total: 56.9s	remaining: 1m 39s
# 109:	learn: 0.1541014	test: 0.1406643	best: 0.1406643 (109)	total: 57.4s	remaining: 1m 39s
# 110:	learn: 0.1540898	test: 0.1406604	best: 0.1406604 (110)	total: 57.8s	remaining: 1m 38s
# 111:	learn: 0.1539958	test: 0.1406504	best: 0.1406504 (111)	total: 58.4s	remaining: 1m 37s
# 112:	learn: 0.1538779	test: 0.1405960	best: 0.1405960 (112)	total: 59.1s	remaining: 1m 37s
# 113:	learn: 0.1537446	test: 0.1406312	best: 0.1405960 (112)	total: 60s	remaining: 1m 37s
# 114:	learn: 0.1536725	test: 0.1405407	best: 0.1405407 (114)	total: 1m	remaining: 1m 37s
# 115:	learn: 0.1536515	test: 0.1405117	best: 0.1405117 (115)	total: 1m 1s	remaining: 1m 37s
# 116:	learn: 0.1533799	test: 0.1403866	best: 0.1403866 (116)	total: 1m 1s	remaining: 1m 36s
# 117:	learn: 0.1532947	test: 0.1403504	best: 0.1403504 (117)	total: 1m 2s	remaining: 1m 36s
# 118:	learn: 0.1532117	test: 0.1403029	best: 0.1403029 (118)	total: 1m 3s	remaining: 1m 35s
# 119:	learn: 0.1531991	test: 0.1402870	best: 0.1402870 (119)	total: 1m 3s	remaining: 1m 35s
# 120:	learn: 0.1531077	test: 0.1402516	best: 0.1402516 (120)	total: 1m 4s	remaining: 1m 34s
# 121:	learn: 0.1529709	test: 0.1402434	best: 0.1402434 (121)	total: 1m 4s	remaining: 1m 34s
# 122:	learn: 0.1529317	test: 0.1401705	best: 0.1401705 (122)	total: 1m 5s	remaining: 1m 34s
# 123:	learn: 0.1529182	test: 0.1401658	best: 0.1401658 (123)	total: 1m 6s	remaining: 1m 33s
# 124:	learn: 0.1527565	test: 0.1400777	best: 0.1400777 (124)	total: 1m 6s	remaining: 1m 33s
# 125:	learn: 0.1527267	test: 0.1400512	best: 0.1400512 (125)	total: 1m 7s	remaining: 1m 33s
# 126:	learn: 0.1527197	test: 0.1400414	best: 0.1400414 (126)	total: 1m 7s	remaining: 1m 32s
# 127:	learn: 0.1524916	test: 0.1398887	best: 0.1398887 (127)	total: 1m 8s	remaining: 1m 32s
# 128:	learn: 0.1524761	test: 0.1398670	best: 0.1398670 (128)	total: 1m 9s	remaining: 1m 31s
# 129:	learn: 0.1524646	test: 0.1399002	best: 0.1398670 (128)	total: 1m 9s	remaining: 1m 31s
# 130:	learn: 0.1524373	test: 0.1399188	best: 0.1398670 (128)	total: 1m 10s	remaining: 1m 30s
# 131:	learn: 0.1523334	test: 0.1398418	best: 0.1398418 (131)	total: 1m 10s	remaining: 1m 30s
# 132:	learn: 0.1522368	test: 0.1397992	best: 0.1397992 (132)	total: 1m 11s	remaining: 1m 29s
# 133:	learn: 0.1521744	test: 0.1397623	best: 0.1397623 (133)	total: 1m 12s	remaining: 1m 29s
# 134:	learn: 0.1521556	test: 0.1397482	best: 0.1397482 (134)	total: 1m 12s	remaining: 1m 28s
# 135:	learn: 0.1520971	test: 0.1397311	best: 0.1397311 (135)	total: 1m 13s	remaining: 1m 28s
# 136:	learn: 0.1520336	test: 0.1396050	best: 0.1396050 (136)	total: 1m 14s	remaining: 1m 28s
# 137:	learn: 0.1519609	test: 0.1395754	best: 0.1395754 (137)	total: 1m 14s	remaining: 1m 27s
# 138:	learn: 0.1519268	test: 0.1395178	best: 0.1395178 (138)	total: 1m 15s	remaining: 1m 27s
# 139:	learn: 0.1519169	test: 0.1395176	best: 0.1395176 (139)	total: 1m 15s	remaining: 1m 26s
# 140:	learn: 0.1518901	test: 0.1395471	best: 0.1395176 (139)	total: 1m 16s	remaining: 1m 26s
# 141:	learn: 0.1517702	test: 0.1395174	best: 0.1395174 (141)	total: 1m 17s	remaining: 1m 25s
# 142:	learn: 0.1517683	test: 0.1395136	best: 0.1395136 (142)	total: 1m 17s	remaining: 1m 25s
# 143:	learn: 0.1517342	test: 0.1394867	best: 0.1394867 (143)	total: 1m 18s	remaining: 1m 24s
# 144:	learn: 0.1517289	test: 0.1394754	best: 0.1394754 (144)	total: 1m 18s	remaining: 1m 24s
# 145:	learn: 0.1517285	test: 0.1394723	best: 0.1394723 (145)	total: 1m 19s	remaining: 1m 23s
# 146:	learn: 0.1517113	test: 0.1394753	best: 0.1394723 (145)	total: 1m 19s	remaining: 1m 23s
# 147:	learn: 0.1516904	test: 0.1395074	best: 0.1394723 (145)	total: 1m 20s	remaining: 1m 22s
# 148:	learn: 0.1516199	test: 0.1394676	best: 0.1394676 (148)	total: 1m 21s	remaining: 1m 22s
# 149:	learn: 0.1515945	test: 0.1394317	best: 0.1394317 (149)	total: 1m 21s	remaining: 1m 21s
# 150:	learn: 0.1514889	test: 0.1393493	best: 0.1393493 (150)	total: 1m 22s	remaining: 1m 21s
# 151:	learn: 0.1514494	test: 0.1393550	best: 0.1393493 (150)	total: 1m 22s	remaining: 1m 20s
# 152:	learn: 0.1514095	test: 0.1393805	best: 0.1393493 (150)	total: 1m 23s	remaining: 1m 20s
# 153:	learn: 0.1513884	test: 0.1394051	best: 0.1393493 (150)	total: 1m 24s	remaining: 1m 19s
# 154:	learn: 0.1513632	test: 0.1394061	best: 0.1393493 (150)	total: 1m 24s	remaining: 1m 19s
# 155:	learn: 0.1513426	test: 0.1394133	best: 0.1393493 (150)	total: 1m 25s	remaining: 1m 18s
# 156:	learn: 0.1512437	test: 0.1394080	best: 0.1393493 (150)	total: 1m 25s	remaining: 1m 18s
# 157:	learn: 0.1511828	test: 0.1393711	best: 0.1393493 (150)	total: 1m 26s	remaining: 1m 17s
# 158:	learn: 0.1511747	test: 0.1393724	best: 0.1393493 (150)	total: 1m 27s	remaining: 1m 17s
# 159:	learn: 0.1511527	test: 0.1393752	best: 0.1393493 (150)	total: 1m 27s	remaining: 1m 16s
# 160:	learn: 0.1511464	test: 0.1393792	best: 0.1393493 (150)	total: 1m 28s	remaining: 1m 16s
# 161:	learn: 0.1511381	test: 0.1393732	best: 0.1393493 (150)	total: 1m 28s	remaining: 1m 15s
# 162:	learn: 0.1509307	test: 0.1392422	best: 0.1392422 (162)	total: 1m 29s	remaining: 1m 15s
# 163:	learn: 0.1508681	test: 0.1392454	best: 0.1392422 (162)	total: 1m 30s	remaining: 1m 14s
# 164:	learn: 0.1507764	test: 0.1392550	best: 0.1392422 (162)	total: 1m 30s	remaining: 1m 14s
# 165:	learn: 0.1507650	test: 0.1392816	best: 0.1392422 (162)	total: 1m 31s	remaining: 1m 13s
# 166:	learn: 0.1507524	test: 0.1392892	best: 0.1392422 (162)	total: 1m 31s	remaining: 1m 13s
# 167:	learn: 0.1507451	test: 0.1392831	best: 0.1392422 (162)	total: 1m 32s	remaining: 1m 12s
# 168:	learn: 0.1507171	test: 0.1392886	best: 0.1392422 (162)	total: 1m 33s	remaining: 1m 12s
# 169:	learn: 0.1507142	test: 0.1392547	best: 0.1392422 (162)	total: 1m 33s	remaining: 1m 11s
# 170:	learn: 0.1507130	test: 0.1392560	best: 0.1392422 (162)	total: 1m 34s	remaining: 1m 11s
# 171:	learn: 0.1506883	test: 0.1392291	best: 0.1392291 (171)	total: 1m 35s	remaining: 1m 10s
# 172:	learn: 0.1506785	test: 0.1392194	best: 0.1392194 (172)	total: 1m 35s	remaining: 1m 10s
# 173:	learn: 0.1506525	test: 0.1392012	best: 0.1392012 (173)	total: 1m 36s	remaining: 1m 9s
# 174:	learn: 0.1506329	test: 0.1392001	best: 0.1392001 (174)	total: 1m 37s	remaining: 1m 9s
# 175:	learn: 0.1504864	test: 0.1391928	best: 0.1391928 (175)	total: 1m 37s	remaining: 1m 8s
# 176:	learn: 0.1504803	test: 0.1392009	best: 0.1391928 (175)	total: 1m 38s	remaining: 1m 8s
# 177:	learn: 0.1502718	test: 0.1393189	best: 0.1391928 (175)	total: 1m 39s	remaining: 1m 7s
# 178:	learn: 0.1502579	test: 0.1392742	best: 0.1391928 (175)	total: 1m 39s	remaining: 1m 7s
# 179:	learn: 0.1501974	test: 0.1392853	best: 0.1391928 (175)	total: 1m 40s	remaining: 1m 6s
# 180:	learn: 0.1501871	test: 0.1392867	best: 0.1391928 (175)	total: 1m 40s	remaining: 1m 6s
# 181:	learn: 0.1501771	test: 0.1392879	best: 0.1391928 (175)	total: 1m 41s	remaining: 1m 5s
# 182:	learn: 0.1501675	test: 0.1392938	best: 0.1391928 (175)	total: 1m 41s	remaining: 1m 5s
# 183:	learn: 0.1500351	test: 0.1391917	best: 0.1391917 (183)	total: 1m 42s	remaining: 1m 4s
# 184:	learn: 0.1498418	test: 0.1391103	best: 0.1391103 (184)	total: 1m 43s	remaining: 1m 4s
# 185:	learn: 0.1497560	test: 0.1391050	best: 0.1391050 (185)	total: 1m 43s	remaining: 1m 3s
# 186:	learn: 0.1496798	test: 0.1390703	best: 0.1390703 (186)	total: 1m 44s	remaining: 1m 3s
# 187:	learn: 0.1495964	test: 0.1389977	best: 0.1389977 (187)	total: 1m 45s	remaining: 1m 2s
# 188:	learn: 0.1495950	test: 0.1389957	best: 0.1389957 (188)	total: 1m 45s	remaining: 1m 1s
# 189:	learn: 0.1495698	test: 0.1390074	best: 0.1389957 (188)	total: 1m 46s	remaining: 1m 1s
# 190:	learn: 0.1495407	test: 0.1389875	best: 0.1389875 (190)	total: 1m 46s	remaining: 1m
# 191:	learn: 0.1494957	test: 0.1389686	best: 0.1389686 (191)	total: 1m 47s	remaining: 1m
# 192:	learn: 0.1494839	test: 0.1389661	best: 0.1389661 (192)	total: 1m 48s	remaining: 59.9s
# 193:	learn: 0.1494776	test: 0.1389849	best: 0.1389661 (192)	total: 1m 48s	remaining: 59.4s
# 194:	learn: 0.1494315	test: 0.1390095	best: 0.1389661 (192)	total: 1m 49s	remaining: 58.8s
# 195:	learn: 0.1494248	test: 0.1390119	best: 0.1389661 (192)	total: 1m 49s	remaining: 58.3s
# 196:	learn: 0.1494039	test: 0.1390037	best: 0.1389661 (192)	total: 1m 50s	remaining: 57.7s
# 197:	learn: 0.1493437	test: 0.1390045	best: 0.1389661 (192)	total: 1m 50s	remaining: 57.1s
# 198:	learn: 0.1493244	test: 0.1389761	best: 0.1389661 (192)	total: 1m 51s	remaining: 56.7s
# 199:	learn: 0.1492388	test: 0.1389834	best: 0.1389661 (192)	total: 1m 52s	remaining: 56.1s
# 200:	learn: 0.1491537	test: 0.1389516	best: 0.1389516 (200)	total: 1m 52s	remaining: 55.6s
# 201:	learn: 0.1490190	test: 0.1388872	best: 0.1388872 (201)	total: 1m 53s	remaining: 55.1s
# 202:	learn: 0.1489245	test: 0.1388646	best: 0.1388646 (202)	total: 1m 54s	remaining: 54.6s
# 203:	learn: 0.1488903	test: 0.1388874	best: 0.1388646 (202)	total: 1m 54s	remaining: 54s
# 204:	learn: 0.1488793	test: 0.1388917	best: 0.1388646 (202)	total: 1m 55s	remaining: 53.5s
# 205:	learn: 0.1488540	test: 0.1388948	best: 0.1388646 (202)	total: 1m 56s	remaining: 52.9s
# 206:	learn: 0.1488160	test: 0.1389199	best: 0.1388646 (202)	total: 1m 56s	remaining: 52.4s
# 207:	learn: 0.1487109	test: 0.1389527	best: 0.1388646 (202)	total: 1m 57s	remaining: 51.9s
# 208:	learn: 0.1486596	test: 0.1389066	best: 0.1388646 (202)	total: 1m 57s	remaining: 51.3s
# 209:	learn: 0.1486357	test: 0.1389177	best: 0.1388646 (202)	total: 1m 58s	remaining: 50.8s
# 210:	learn: 0.1486332	test: 0.1389542	best: 0.1388646 (202)	total: 1m 59s	remaining: 50.2s
# 211:	learn: 0.1486272	test: 0.1389526	best: 0.1388646 (202)	total: 1m 59s	remaining: 49.7s
# 212:	learn: 0.1486161	test: 0.1389412	best: 0.1388646 (202)	total: 2m	remaining: 49.1s
# 213:	learn: 0.1486085	test: 0.1389546	best: 0.1388646 (202)	total: 2m 1s	remaining: 48.6s
# 214:	learn: 0.1485794	test: 0.1389229	best: 0.1388646 (202)	total: 2m 1s	remaining: 48s
# 215:	learn: 0.1485738	test: 0.1389161	best: 0.1388646 (202)	total: 2m 2s	remaining: 47.5s
# 216:	learn: 0.1484969	test: 0.1389393	best: 0.1388646 (202)	total: 2m 2s	remaining: 46.9s
# 217:	learn: 0.1484751	test: 0.1389628	best: 0.1388646 (202)	total: 2m 3s	remaining: 46.4s
# 218:	learn: 0.1484585	test: 0.1389574	best: 0.1388646 (202)	total: 2m 3s	remaining: 45.8s
# 219:	learn: 0.1484551	test: 0.1389660	best: 0.1388646 (202)	total: 2m 4s	remaining: 45.3s
# 220:	learn: 0.1484446	test: 0.1389849	best: 0.1388646 (202)	total: 2m 5s	remaining: 44.7s
# 221:	learn: 0.1484029	test: 0.1389774	best: 0.1388646 (202)	total: 2m 5s	remaining: 44.2s
# 222:	learn: 0.1484003	test: 0.1389863	best: 0.1388646 (202)	total: 2m 6s	remaining: 43.6s
# 223:	learn: 0.1483993	test: 0.1389894	best: 0.1388646 (202)	total: 2m 6s	remaining: 43.1s
# 224:	learn: 0.1483189	test: 0.1389861	best: 0.1388646 (202)	total: 2m 7s	remaining: 42.5s
# 225:	learn: 0.1482549	test: 0.1390089	best: 0.1388646 (202)	total: 2m 8s	remaining: 42s
# 226:	learn: 0.1482233	test: 0.1390608	best: 0.1388646 (202)	total: 2m 8s	remaining: 41.4s
# 227:	learn: 0.1482005	test: 0.1390691	best: 0.1388646 (202)	total: 2m 9s	remaining: 40.9s
# 228:	learn: 0.1481902	test: 0.1390864	best: 0.1388646 (202)	total: 2m 10s	remaining: 40.3s
# 229:	learn: 0.1481803	test: 0.1391269	best: 0.1388646 (202)	total: 2m 10s	remaining: 39.8s
# 230:	learn: 0.1481316	test: 0.1391114	best: 0.1388646 (202)	total: 2m 11s	remaining: 39.3s
# 231:	learn: 0.1479854	test: 0.1391538	best: 0.1388646 (202)	total: 2m 12s	remaining: 38.7s
# ...
# 126:	learn: 0.1535339	test: 0.1394674	best: 0.1394224 (123)	total: 1m 8s	remaining: 1m 32s
# 127:	learn: 0.1535157	test: 0.1394833	best: 0.1394224 (123)	total: 1m 8s	remaining: 1m 32s
# 128:	learn: 0.1534672	test: 0.1395036	best: 0.1394224 (123)	total: 1m 9s	remaining: 1m 32s
# 129:	learn: 0.1534600	test: 0.1395039	best: 0.1394224 (123)	total: 1m 10s	remaining: 1m 32s
# 130:	learn: 0.1533117	test: 0.1394227	best: 0.1394224 (123)	total: 1m 11s	remaining: 1m 31s
# 131:	learn: 0.1532846	test: 0.1394114	best: 0.1394114 (131)	total: 1m 11s	remaining: 1m 31s
# 132:	learn: 0.1532273	test: 0.1393578	best: 0.1393578 (132)	total: 1m 12s	remaining: 1m 30s
# 133:	learn: 0.1531457	test: 0.1393295	best: 0.1393295 (133)	total: 1m 13s	remaining: 1m 30s
# 134:	learn: 0.1531345	test: 0.1393504	best: 0.1393295 (133)	total: 1m 13s	remaining: 1m 30s
# 135:	learn: 0.1531299	test: 0.1393626	best: 0.1393295 (133)	total: 1m 14s	remaining: 1m 29s
# 136:	learn: 0.1530671	test: 0.1393777	best: 0.1393295 (133)	total: 1m 14s	remaining: 1m 29s
# 137:	learn: 0.1530517	test: 0.1393870	best: 0.1393295 (133)	total: 1m 15s	remaining: 1m 28s
# 138:	learn: 0.1529681	test: 0.1394151	best: 0.1393295 (133)	total: 1m 16s	remaining: 1m 28s
# 139:	learn: 0.1529039	test: 0.1395329	best: 0.1393295 (133)	total: 1m 16s	remaining: 1m 27s
# 140:	learn: 0.1528962	test: 0.1395371	best: 0.1393295 (133)	total: 1m 17s	remaining: 1m 27s
# 141:	learn: 0.1528090	test: 0.1395909	best: 0.1393295 (133)	total: 1m 18s	remaining: 1m 26s
# 142:	learn: 0.1527789	test: 0.1395542	best: 0.1393295 (133)	total: 1m 18s	remaining: 1m 26s
# 143:	learn: 0.1527310	test: 0.1395289	best: 0.1393295 (133)	total: 1m 19s	remaining: 1m 25s
# 144:	learn: 0.1526853	test: 0.1395306	best: 0.1393295 (133)	total: 1m 20s	remaining: 1m 25s
# 145:	learn: 0.1526572	test: 0.1394884	best: 0.1393295 (133)	total: 1m 20s	remaining: 1m 25s
# 146:	learn: 0.1526469	test: 0.1395009	best: 0.1393295 (133)	total: 1m 21s	remaining: 1m 24s
# 147:	learn: 0.1525945	test: 0.1395056	best: 0.1393295 (133)	total: 1m 21s	remaining: 1m 24s
# 148:	learn: 0.1525256	test: 0.1394764	best: 0.1393295 (133)	total: 1m 22s	remaining: 1m 23s
# 149:	learn: 0.1525192	test: 0.1394821	best: 0.1393295 (133)	total: 1m 23s	remaining: 1m 23s
# 150:	learn: 0.1523867	test: 0.1394840	best: 0.1393295 (133)	total: 1m 23s	remaining: 1m 22s
# 151:	learn: 0.1522772	test: 0.1394334	best: 0.1393295 (133)	total: 1m 24s	remaining: 1m 22s
# 152:	learn: 0.1521910	test: 0.1394124	best: 0.1393295 (133)	total: 1m 25s	remaining: 1m 21s
# 153:	learn: 0.1521547	test: 0.1394057	best: 0.1393295 (133)	total: 1m 25s	remaining: 1m 21s
# 154:	learn: 0.1520049	test: 0.1393497	best: 0.1393295 (133)	total: 1m 26s	remaining: 1m 20s
# 155:	learn: 0.1519994	test: 0.1393515	best: 0.1393295 (133)	total: 1m 26s	remaining: 1m 20s
# 156:	learn: 0.1518608	test: 0.1393721	best: 0.1393295 (133)	total: 1m 27s	remaining: 1m 19s
# 157:	learn: 0.1518218	test: 0.1393986	best: 0.1393295 (133)	total: 1m 28s	remaining: 1m 19s
# 158:	learn: 0.1517582	test: 0.1394061	best: 0.1393295 (133)	total: 1m 28s	remaining: 1m 18s
# 159:	learn: 0.1515474	test: 0.1393950	best: 0.1393295 (133)	total: 1m 29s	remaining: 1m 18s
# 160:	learn: 0.1515262	test: 0.1393856	best: 0.1393295 (133)	total: 1m 30s	remaining: 1m 17s
# 161:	learn: 0.1514536	test: 0.1393323	best: 0.1393295 (133)	total: 1m 30s	remaining: 1m 17s
# 162:	learn: 0.1514380	test: 0.1393719	best: 0.1393295 (133)	total: 1m 31s	remaining: 1m 16s
# 163:	learn: 0.1513923	test: 0.1393137	best: 0.1393137 (163)	total: 1m 32s	remaining: 1m 16s
# 164:	learn: 0.1513556	test: 0.1393702	best: 0.1393137 (163)	total: 1m 32s	remaining: 1m 15s
# 165:	learn: 0.1513466	test: 0.1393834	best: 0.1393137 (163)	total: 1m 33s	remaining: 1m 15s
# 166:	learn: 0.1513177	test: 0.1393597	best: 0.1393137 (163)	total: 1m 34s	remaining: 1m 14s
# 167:	learn: 0.1511211	test: 0.1392699	best: 0.1392699 (167)	total: 1m 34s	remaining: 1m 14s
# 168:	learn: 0.1511011	test: 0.1392754	best: 0.1392699 (167)	total: 1m 35s	remaining: 1m 13s
# 169:	learn: 0.1510926	test: 0.1392810	best: 0.1392699 (167)	total: 1m 35s	remaining: 1m 13s
# 170:	learn: 0.1509337	test: 0.1392320	best: 0.1392320 (170)	total: 1m 36s	remaining: 1m 12s
# 171:	learn: 0.1508710	test: 0.1392130	best: 0.1392130 (171)	total: 1m 37s	remaining: 1m 12s
# 172:	learn: 0.1508519	test: 0.1391871	best: 0.1391871 (172)	total: 1m 37s	remaining: 1m 11s
# 173:	learn: 0.1508055	test: 0.1391756	best: 0.1391756 (173)	total: 1m 38s	remaining: 1m 11s
# 174:	learn: 0.1507977	test: 0.1392125	best: 0.1391756 (173)	total: 1m 38s	remaining: 1m 10s
# 175:	learn: 0.1507724	test: 0.1391613	best: 0.1391613 (175)	total: 1m 39s	remaining: 1m 10s
# 176:	learn: 0.1506018	test: 0.1390181	best: 0.1390181 (176)	total: 1m 40s	remaining: 1m 9s
# 177:	learn: 0.1504508	test: 0.1389968	best: 0.1389968 (177)	total: 1m 40s	remaining: 1m 9s
# 178:	learn: 0.1503774	test: 0.1389973	best: 0.1389968 (177)	total: 1m 41s	remaining: 1m 8s
# 179:	learn: 0.1502026	test: 0.1386884	best: 0.1386884 (179)	total: 1m 42s	remaining: 1m 8s
# 180:	learn: 0.1501943	test: 0.1386842	best: 0.1386842 (180)	total: 1m 42s	remaining: 1m 7s
# 181:	learn: 0.1501272	test: 0.1386813	best: 0.1386813 (181)	total: 1m 43s	remaining: 1m 7s
# 182:	learn: 0.1501229	test: 0.1386792	best: 0.1386792 (182)	total: 1m 43s	remaining: 1m 6s
# 183:	learn: 0.1500935	test: 0.1387437	best: 0.1386792 (182)	total: 1m 44s	remaining: 1m 5s
# 184:	learn: 0.1500110	test: 0.1386814	best: 0.1386792 (182)	total: 1m 45s	remaining: 1m 5s
# 185:	learn: 0.1500066	test: 0.1386797	best: 0.1386792 (182)	total: 1m 45s	remaining: 1m 4s
# 186:	learn: 0.1499533	test: 0.1387152	best: 0.1386792 (182)	total: 1m 46s	remaining: 1m 4s
# 187:	learn: 0.1499383	test: 0.1387029	best: 0.1386792 (182)	total: 1m 47s	remaining: 1m 3s
# 188:	learn: 0.1499016	test: 0.1387417	best: 0.1386792 (182)	total: 1m 47s	remaining: 1m 3s
# 189:	learn: 0.1498879	test: 0.1387266	best: 0.1386792 (182)	total: 1m 48s	remaining: 1m 2s
# 190:	learn: 0.1498469	test: 0.1387337	best: 0.1386792 (182)	total: 1m 48s	remaining: 1m 2s
# 191:	learn: 0.1497815	test: 0.1386840	best: 0.1386792 (182)	total: 1m 49s	remaining: 1m 1s
# 192:	learn: 0.1497672	test: 0.1386884	best: 0.1386792 (182)	total: 1m 50s	remaining: 1m 1s
# 193:	learn: 0.1497390	test: 0.1386931	best: 0.1386792 (182)	total: 1m 50s	remaining: 1m
# 194:	learn: 0.1496788	test: 0.1386828	best: 0.1386792 (182)	total: 1m 51s	remaining: 1m
# 195:	learn: 0.1496588	test: 0.1386885	best: 0.1386792 (182)	total: 1m 52s	remaining: 59.5s
# 196:	learn: 0.1495128	test: 0.1387370	best: 0.1386792 (182)	total: 1m 52s	remaining: 59s
# 197:	learn: 0.1495120	test: 0.1387374	best: 0.1386792 (182)	total: 1m 53s	remaining: 58.4s
# 198:	learn: 0.1493992	test: 0.1387825	best: 0.1386792 (182)	total: 1m 54s	remaining: 57.9s
# 199:	learn: 0.1493499	test: 0.1388386	best: 0.1386792 (182)	total: 1m 54s	remaining: 57.4s
# 200:	learn: 0.1493431	test: 0.1388690	best: 0.1386792 (182)	total: 1m 55s	remaining: 56.8s
# 201:	learn: 0.1492750	test: 0.1387768	best: 0.1386792 (182)	total: 1m 55s	remaining: 56.2s
# 202:	learn: 0.1492611	test: 0.1387692	best: 0.1386792 (182)	total: 1m 56s	remaining: 55.7s
# 203:	learn: 0.1492173	test: 0.1388575	best: 0.1386792 (182)	total: 1m 57s	remaining: 55.2s
# 204:	learn: 0.1491494	test: 0.1388455	best: 0.1386792 (182)	total: 1m 57s	remaining: 54.6s
# 205:	learn: 0.1490900	test: 0.1389294	best: 0.1386792 (182)	total: 1m 58s	remaining: 54.1s
# 206:	learn: 0.1490787	test: 0.1389269	best: 0.1386792 (182)	total: 1m 59s	remaining: 53.5s
# 207:	learn: 0.1490769	test: 0.1389230	best: 0.1386792 (182)	total: 1m 59s	remaining: 53s
# 208:	learn: 0.1490371	test: 0.1389290	best: 0.1386792 (182)	total: 2m	remaining: 52.4s
# 209:	learn: 0.1489713	test: 0.1388780	best: 0.1386792 (182)	total: 2m 1s	remaining: 51.9s
# 210:	learn: 0.1489587	test: 0.1388668	best: 0.1386792 (182)	total: 2m 1s	remaining: 51.3s
# 211:	learn: 0.1489216	test: 0.1388656	best: 0.1386792 (182)	total: 2m 2s	remaining: 50.7s
# 212:	learn: 0.1488847	test: 0.1388149	best: 0.1386792 (182)	total: 2m 2s	remaining: 50.2s
# 213:	learn: 0.1488789	test: 0.1388104	best: 0.1386792 (182)	total: 2m 3s	remaining: 49.6s
# 214:	learn: 0.1487797	test: 0.1387987	best: 0.1386792 (182)	total: 2m 4s	remaining: 49s
# 215:	learn: 0.1486962	test: 0.1387658	best: 0.1386792 (182)	total: 2m 4s	remaining: 48.5s
# 216:	learn: 0.1486895	test: 0.1387652	best: 0.1386792 (182)	total: 2m 5s	remaining: 47.9s
# 217:	learn: 0.1486847	test: 0.1387717	best: 0.1386792 (182)	total: 2m 5s	remaining: 47.4s
# 218:	learn: 0.1486649	test: 0.1387635	best: 0.1386792 (182)	total: 2m 6s	remaining: 46.8s
# 219:	learn: 0.1486134	test: 0.1387100	best: 0.1386792 (182)	total: 2m 7s	remaining: 46.3s
# 220:	learn: 0.1485933	test: 0.1387124	best: 0.1386792 (182)	total: 2m 7s	remaining: 45.7s
# 221:	learn: 0.1485929	test: 0.1387126	best: 0.1386792 (182)	total: 2m 8s	remaining: 45.2s
# 222:	learn: 0.1485619	test: 0.1387048	best: 0.1386792 (182)	total: 2m 9s	remaining: 44.6s
# 223:	learn: 0.1484640	test: 0.1386545	best: 0.1386545 (223)	total: 2m 9s	remaining: 44s
# 224:	learn: 0.1484564	test: 0.1386509	best: 0.1386509 (224)	total: 2m 10s	remaining: 43.5s
# 225:	learn: 0.1483058	test: 0.1386490	best: 0.1386490 (225)	total: 2m 11s	remaining: 42.9s
# 226:	learn: 0.1482605	test: 0.1386593	best: 0.1386490 (225)	total: 2m 11s	remaining: 42.3s
# 227:	learn: 0.1482315	test: 0.1386702	best: 0.1386490 (225)	total: 2m 12s	remaining: 41.8s
# 228:	learn: 0.1482034	test: 0.1387256	best: 0.1386490 (225)	total: 2m 12s	remaining: 41.2s
# 229:	learn: 0.1482030	test: 0.1387266	best: 0.1386490 (225)	total: 2m 13s	remaining: 40.6s
# 230:	learn: 0.1481217	test: 0.1387124	best: 0.1386490 (225)	total: 2m 14s	remaining: 40s
# 231:	learn: 0.1481093	test: 0.1387206	best: 0.1386490 (225)	total: 2m 14s	remaining: 39.5s
# 232:	learn: 0.1480951	test: 0.1387203	best: 0.1386490 (225)	total: 2m 15s	remaining: 38.9s
# 233:	learn: 0.1480222	test: 0.1386772	best: 0.1386490 (225)	total: 2m 16s	remaining: 38.4s
# 234:	learn: 0.1479678	test: 0.1386151	best: 0.1386151 (234)	total: 2m 16s	remaining: 37.8s
# 235:	learn: 0.1479543	test: 0.1386031	best: 0.1386031 (235)	total: 2m 17s	remaining: 37.2s
# 236:	learn: 0.1479461	test: 0.1386335	best: 0.1386031 (235)	total: 2m 17s	remaining: 36.7s
# 237:	learn: 0.1479392	test: 0.1386657	best: 0.1386031 (235)	total: 2m 18s	remaining: 36.1s
# 238:	learn: 0.1479347	test: 0.1386585	best: 0.1386031 (235)	total: 2m 19s	remaining: 35.5s
# 239:	learn: 0.1479094	test: 0.1387089	best: 0.1386031 (235)	total: 2m 19s	remaining: 35s
# 240:	learn: 0.1478870	test: 0.1387089	best: 0.1386031 (235)	total: 2m 20s	remaining: 34.4s
# 241:	learn: 0.1478680	test: 0.1387222	best: 0.1386031 (235)	total: 2m 21s	remaining: 33.8s
# 242:	learn: 0.1478669	test: 0.1387232	best: 0.1386031 (235)	total: 2m 21s	remaining: 33.2s
# 243:	learn: 0.1478456	test: 0.1387457	best: 0.1386031 (235)	total: 2m 22s	remaining: 32.6s
# 244:	learn: 0.1478045	test: 0.1387704	best: 0.1386031 (235)	total: 2m 22s	remaining: 32.1s
# 245:	learn: 0.1478012	test: 0.1387781	best: 0.1386031 (235)	total: 2m 23s	remaining: 31.5s
# 246:	learn: 0.1477315	test: 0.1387418	best: 0.1386031 (235)	total: 2m 24s	remaining: 30.9s
# 247:	learn: 0.1476904	test: 0.1387260	best: 0.1386031 (235)	total: 2m 24s	remaining: 30.4s
# 248:	learn: 0.1476157	test: 0.1386858	best: 0.1386031 (235)	total: 2m 25s	remaining: 29.8s
# 249:	learn: 0.1475830	test: 0.1386803	best: 0.1386031 (235)	total: 2m 26s	remaining: 29.2s
# 250:	learn: 0.1475763	test: 0.1386582	best: 0.1386031 (235)	total: 2m 26s	remaining: 28.7s
# 251:	learn: 0.1475705	test: 0.1386599	best: 0.1386031 (235)	total: 2m 27s	remaining: 28.1s
# 252:	learn: 0.1475516	test: 0.1386667	best: 0.1386031 (235)	total: 2m 28s	remaining: 27.5s
# 253:	learn: 0.1473526	test: 0.1385454	best: 0.1385454 (253)	total: 2m 28s	remaining: 26.9s
# 254:	learn: 0.1473424	test: 0.1385392	best: 0.1385392 (254)	total: 2m 29s	remaining: 26.4s
# 255:	learn: 0.1473310	test: 0.1385243	best: 0.1385243 (255)	total: 2m 30s	remaining: 25.8s
# 256:	learn: 0.1473282	test: 0.1385355	best: 0.1385243 (255)	total: 2m 30s	remaining: 25.2s
# 257:	learn: 0.1472575	test: 0.1385375	best: 0.1385243 (255)	total: 2m 31s	remaining: 24.6s
# 258:	learn: 0.1472552	test: 0.1385401	best: 0.1385243 (255)	total: 2m 31s	remaining: 24s
# 259:	learn: 0.1472254	test: 0.1385384	best: 0.1385243 (255)	total: 2m 32s	remaining: 23.4s
# 260:	learn: 0.1472217	test: 0.1385322	best: 0.1385243 (255)	total: 2m 32s	remaining: 22.8s
# 261:	learn: 0.1470576	test: 0.1386171	best: 0.1385243 (255)	total: 2m 33s	remaining: 22.3s
# 262:	learn: 0.1470545	test: 0.1386197	best: 0.1385243 (255)	total: 2m 34s	remaining: 21.7s
# 263:	learn: 0.1470373	test: 0.1386214	best: 0.1385243 (255)	total: 2m 34s	remaining: 21.1s
# 264:	learn: 0.1470043	test: 0.1386517	best: 0.1385243 (255)	total: 2m 35s	remaining: 20.6s
# 265:	learn: 0.1469984	test: 0.1386523	best: 0.1385243 (255)	total: 2m 36s	remaining: 20s
# 266:	learn: 0.1469786	test: 0.1386721	best: 0.1385243 (255)	total: 2m 36s	remaining: 19.4s
# 267:	learn: 0.1469659	test: 0.1386695	best: 0.1385243 (255)	total: 2m 37s	remaining: 18.8s
# 268:	learn: 0.1469658	test: 0.1386667	best: 0.1385243 (255)	total: 2m 38s	remaining: 18.2s
# 269:	learn: 0.1469612	test: 0.1386687	best: 0.1385243 (255)	total: 2m 38s	remaining: 17.6s
# 270:	learn: 0.1469334	test: 0.1386425	best: 0.1385243 (255)	total: 2m 39s	remaining: 17s
# 271:	learn: 0.1468970	test: 0.1386072	best: 0.1385243 (255)	total: 2m 39s	remaining: 16.5s
# 272:	learn: 0.1468797	test: 0.1386101	best: 0.1385243 (255)	total: 2m 40s	remaining: 15.9s
# 273:	learn: 0.1467503	test: 0.1386446	best: 0.1385243 (255)	total: 2m 41s	remaining: 15.3s
# 274:	learn: 0.1466945	test: 0.1386406	best: 0.1385243 (255)	total: 2m 41s	remaining: 14.7s
# 275:	learn: 0.1466245	test: 0.1385812	best: 0.1385243 (255)	total: 2m 42s	remaining: 14.1s
# 276:	learn: 0.1466190	test: 0.1385891	best: 0.1385243 (255)	total: 2m 43s	remaining: 13.6s
# 277:	learn: 0.1466035	test: 0.1386031	best: 0.1385243 (255)	total: 2m 43s	remaining: 13s
# 278:	learn: 0.1465897	test: 0.1386134	best: 0.1385243 (255)	total: 2m 44s	remaining: 12.4s
# 279:	learn: 0.1465877	test: 0.1386272	best: 0.1385243 (255)	total: 2m 45s	remaining: 11.8s
# 280:	learn: 0.1465837	test: 0.1386178	best: 0.1385243 (255)	total: 2m 45s	remaining: 11.2s
# 281:	learn: 0.1465183	test: 0.1386111	best: 0.1385243 (255)	total: 2m 46s	remaining: 10.6s
# 282:	learn: 0.1465147	test: 0.1386047	best: 0.1385243 (255)	total: 2m 46s	remaining: 10s
# 283:	learn: 0.1465094	test: 0.1386076	best: 0.1385243 (255)	total: 2m 47s	remaining: 9.44s
# 284:	learn: 0.1464994	test: 0.1386057	best: 0.1385243 (255)	total: 2m 48s	remaining: 8.85s
# 285:	learn: 0.1464898	test: 0.1385865	best: 0.1385243 (255)	total: 2m 48s	remaining: 8.26s
# 286:	learn: 0.1464520	test: 0.1385792	best: 0.1385243 (255)	total: 2m 49s	remaining: 7.67s
# 287:	learn: 0.1463916	test: 0.1386036	best: 0.1385243 (255)	total: 2m 50s	remaining: 7.09s
# 288:	learn: 0.1463166	test: 0.1386754	best: 0.1385243 (255)	total: 2m 50s	remaining: 6.5s
# 289:	learn: 0.1462673	test: 0.1387248	best: 0.1385243 (255)	total: 2m 51s	remaining: 5.91s
# 290:	learn: 0.1461656	test: 0.1386663	best: 0.1385243 (255)	total: 2m 51s	remaining: 5.32s
# 291:	learn: 0.1461409	test: 0.1386643	best: 0.1385243 (255)	total: 2m 52s	remaining: 4.73s
# 292:	learn: 0.1460968	test: 0.1386672	best: 0.1385243 (255)	total: 2m 53s	remaining: 4.14s
# 293:	learn: 0.1460926	test: 0.1386665	best: 0.1385243 (255)	total: 2m 53s	remaining: 3.55s
# 294:	learn: 0.1460917	test: 0.1386591	best: 0.1385243 (255)	total: 2m 54s	remaining: 2.96s
# 295:	learn: 0.1459399	test: 0.1386884	best: 0.1385243 (255)	total: 2m 55s	remaining: 2.37s
# 296:	learn: 0.1459392	test: 0.1386862	best: 0.1385243 (255)	total: 2m 55s	remaining: 1.77s
# 297:	learn: 0.1459282	test: 0.1386800	best: 0.1385243 (255)	total: 2m 56s	remaining: 1.18s
# 298:	learn: 0.1459244	test: 0.1386756	best: 0.1385243 (255)	total: 2m 56s	remaining: 592ms
# 299:	learn: 0.1458973	test: 0.1386866	best: 0.1385243 (255)	total: 2m 57s	remaining: 0us
#
# bestTest = 0.1385242849
# bestIteration = 255
#
# Shrink model to first 256 iterations.

# %%
mean = np.mean(logloss)
grader.submit_tag('logloss_mean', mean)
# Out:
# Current answer for task logloss_mean is: 0.138666044195

# %% [markdown]
# **Question 5:**
#
# What is the standard deviation of it?

# %%
stddev = np.std(logloss)
grader.submit_tag('logloss_std', stddev)
# Out:
# Current answer for task logloss_std is: 0.000637032346134

# %% [markdown]
# ## Metrics calculation and graph plotting

# %% [markdown]
# When experimenting with Jupyter notebook you can see graphs of different errors during training.
# To do that you need to use `plot=True` parameter.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=50,
    random_seed=63,
    learning_rate=0.1,
    custom_loss=['Accuracy']
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
    logging_level='Silent',
    plot=True
)

# %% [markdown]
# **Question 6:**
#
# What is the value of the accuracy metric value on evaluation dataset after training with parameters `iterations=50`, `random_seed=63`, `learning_rate=0.1`?

# %%
accuracy = 0
grader.submit_tag('accuracy_6', accuracy)

# %% [markdown]
# ## Model comparison

# %%
model1 = CatBoostClassifier(
    learning_rate=0.5,
    iterations=1000,
    random_seed=64,
    train_dir='learning_rate_0.5',
    custom_loss = ['Accuracy']
)

model2 = CatBoostClassifier(
    learning_rate=0.05,
    iterations=1000,
    random_seed=64,
    train_dir='learning_rate_0.05',
    custom_loss = ['Accuracy']
)
model1.fit(
    X_train, y_train,
    eval_set=(X_validation, y_validation),
    cat_features=cat_features,
    verbose=100
)
model2.fit(
    X_train, y_train,
    eval_set=(X_validation, y_validation),
    cat_features=cat_features,
    verbose=100
)

# %%
from catboost import MetricVisualizer
MetricVisualizer(['learning_rate_0.05', 'learning_rate_0.5']).start()

# %% [markdown]
# **Question 7:**
#
# Try training these models for 1000 iterations. Which model will give better best resulting Accuracy on validation dataset?
# By best resulting accuracy we mean accuracy on best iteration, which might be not the last iteration.

# %%
best_model_name =  # one of 'learning_rate_0.5', 'learning_rate_0.05'
grader.submit_tag('best_model_name', best_model_name)

# %% [markdown]
# ## Best iteration

# %% [markdown]
# If a validation dataset is present then after training, the model is shrinked to a number of trees when it got best evaluation metric value on validation dataset.
# By default evaluation metric is the optimized metric. But you can set evaluation metric to some other metric.
# In the example below evaluation metric is `Accuracy`.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=100,
    random_seed=63,
    learning_rate=0.5,
    eval_metric='Accuracy'
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
    logging_level='Silent',
    plot=True
)

# %%
print('Tree count: ' + str(model.tree_count_))

# %% [markdown]
# If you don't want the model to be shrinked, you can set `use_best_model=False`

# %%
model = CatBoostClassifier(
    iterations=100,
    random_seed=63,
    learning_rate=0.5,
    eval_metric='Accuracy',
    use_best_model=False
)
model.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
    logging_level='Silent',
    plot=True
)

# %% [markdown]
# **Question 8:**
#
# What will be the number of trees in the resulting model after training with validation dataset with parameters `iterations=100`, ` learning_rate=0.5`, `eval_metric='Accuracy'` and with parameter `use_best_model=False`

# %%
tree_count = 0
grader.submit_tag('num_trees', tree_count)

# %% [markdown]
# ## Cross-validation

# %% [markdown]
# The next functionality you need to know about is cross-validation.
# For unbalanced datasets stratified cross-validation can be useful.

# %%
from catboost import cv

params = {}
params['loss_function'] = 'Logloss'
params['iterations'] = 80
params['custom_loss'] = 'AUC'
params['random_seed'] = 63
params['learning_rate'] = 0.5

cv_data = cv(
    params = params,
    pool = Pool(X, label=y, cat_features=cat_features),
    fold_count=5,
    inverted=False,
    shuffle=True,
    partition_random_seed=0,
    plot=True,
    stratified=True,
    verbose=False
)

# %% [markdown]
# Cross-validation returns specified metric values on every iteration (or every k-th iteration, if you specify so)

# %%
print(cv_data[0:4])

# %% [markdown]
# Let's look on mean value and standard deviation of Logloss for cv on best iteration.

# %%
best_value = np.min(cv_data['test-Logloss-mean'])
best_iter = np.argmin(cv_data['test-Logloss-mean'])

print('Best validation Logloss score, not stratified: {:.4f}±{:.4f} on step {}'.format(
    best_value,
    cv_data['test-Logloss-std'][best_iter],
    best_iter)
)

# %% [markdown]
# **Question 9:**
#
# Try running stratified cross-validation with the same parameters. What will be mean of Logloss metric on test of the stratified cross-validation on the best iteration?

# %%
mean_on_best_iteration = 0
grader.submit_tag('mean_logloss_cv', mean_on_best_iteration)

# %% [markdown]
# **Question 10:**
#
# Try running stratified cross-validation with the same parameters. What will be the standard deviation of Logloss metric of the stratified cross-validation on the best iteration?

# %%
std_on_best_iteration = 0
grader.submit_tag('logloss_std_1', std_on_best_iteration)

# %% [markdown]
# ## Overfitting detector

# %% [markdown]
# A useful feature of the library is overfitting detector.
# Let's try training the model with early stopping.

# %%
model_with_early_stop = CatBoostClassifier(
    iterations=200,
    random_seed=63,
    learning_rate=0.5,
    od_type='Iter',
    od_wait=20,
    eval_metric = 'AUC'
)
model_with_early_stop.fit(
    X_train, y_train,
    cat_features=cat_features,
    eval_set=(X_validation, y_validation),
    logging_level='Silent',
    plot=True
)

# %% [markdown]
# **Question 11:**
#
# Now try training the model with the same parameters and with overfitting detector, but with `eval_metric='AUC'`
# What will be the number of iterations after which the training will stop?
# (Not the number of trees in the resulting model, but the number of iterations that the algorithm will perform befor training).

# %%
iterations_count = 0
grader.submit_tag('iterations_overfitting', iterations_count)

# %% [markdown]
# ## Snapshotting

# %% [markdown]
# If you train for long time, for example for several hours, you need to save snapshots.
# Otherwise if your laptop or your server will reboot, you will loose all the progress.
# To do that you need to specify `snapshot_file` parameter.
# Try running the code below and interrupting the kernel after short time.
# Then try running the same cell again.
# The training will start from the iteration when the training was interrupted.
# Note that all additional files are written by default into `catboost_info` directory. It can be changed using `train_dir` parameter. So the snapshot file will be there.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=40,
    save_snapshot=True,
    snapshot_file='snapshot.bkp',
    random_seed=43
)
model.fit(
    X_train, y_train,
    eval_set=(X_validation, y_validation),
    cat_features=cat_features,
    logging_level='Verbose'
)

# %% [markdown]
# ## Model predictions

# %% [markdown]
# There are multiple ways to do predictions.
# The easiest one is to call predict or predict_proba.
# You also can make predictions using C++ code. For that see [documentation](https://tech.yandex.com/catboost/doc/dg/concepts/c-plus-plus-api-docpage/).

# %%
print(model.predict_proba(data=X_validation))

# %%
print(model.predict(data=X_validation))

# %% [markdown]
# For binary classification resulting value is not necessary a value in `[0,1]`. It is some numeric value. To get the probability out of this value you need to calculate sigmoid of that value.

# %%
raw_pred = model.predict(data=X_validation, prediction_type='RawFormulaVal')
print(raw_pred)

# %%
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))
probabilities = [sigmoid(x) for x in raw_pred]
print(np.array(probabilities))

# %% [markdown]
# ## Staged prediction

# %% [markdown]
# CatBoost also supports staged prediction - when you want to have a prediction on each object on each iteration (or on each k-th iteration). This can be used if you want to calculate the values of some custom metric using the predictions.

# %%
predictions_gen = model.staged_predict_proba(data=X_validation, ntree_start=0, ntree_end=5, eval_period=1)
for iteration, predictions in enumerate(predictions_gen):
    print('Iteration ' + str(iteration) + ', predictions:')
    print(predictions)

# %% [markdown]
# ## Metric evaluation on a new dataset

# %% [markdown]
# You can also calculate metrics directly after training.

# %%
metrics = model.eval_metrics(data=pool1, metrics=['Logloss','AUC'], plot=True)

# %%
print('AUC values:')
print(np.array(metrics['AUC']))

# %% [markdown]
# **Question 12:**
#
# Now train a model in the following way:
#
# `
# from catboost import CatBoostClassifier
# model = CatBoostClassifier(
#     iterations=1000,
#     learning_rate=0.05,
#     random_seed=43
# )
# model.fit(
#     X_train, y_train,
#     eval_set=(X_validation, y_validation),
#     cat_features=cat_features,
#     logging_level='Verbose'
# )
# `
#
# What will be the AUC value on 550 iteration if evaluation metrics on the initial X dataset?

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=1000,
    learning_rate=0.05,
    random_seed=43
)
model.fit(
    X_train, y_train,
    eval_set=(X_validation, y_validation),
    cat_features=cat_features,
    logging_level='Verbose'
)

# %%
auc_value = 0
grader.submit_tag('auc_550', auc_value)

# %% [markdown]
# ## Feature importances

# %% [markdown]
# Now we will learn how to understand which features are the most important ones. Let's first train the model that will not use feature combinations. To forbid feature combinations you need to use 'max_ctr_complexity=1'. This will speed up the training by a lot, but it will reduce the resulting quality.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=300,
    max_ctr_complexity=4,
    random_seed=43
)
model.fit(
    X, y,
    cat_features=cat_features,
    verbose=50
)

# %% [markdown]
# Let's see which features are most important for the model without feature combinations.

# %%
importances = model.get_feature_importance(prettified=True)
print(importances)

# %% [markdown]
# ** Question 13: **
#
# Try training the model without the restriction of combinations, with other parameters set to the same values.
# What will be top 3 most important features for this model?

# %%
top3 = # You should provide comma separated list of strings. Each string should be in single quotes. All list should be in square brackets.
grader.submit_tag('feature_importance_top3', top3)

# %% [markdown]
# ## Shap values

# %% [markdown]
# Let's train the model one more time.

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier(
    iterations=300,
    max_ctr_complexity=1,
    random_seed=43
)
model.fit(
    X, y,
    cat_features=cat_features,
    verbose=50
)

# %% [markdown]
# The library provides a way to understand which features are important for a given object.
# Let's take a look on the whole dataset X and analyze the influence of different features on the objects from this dataset.
# We will now calculate importances for each object. After that we will visualize these importances.

# %%
pool1 = Pool(data=X, label=y, cat_features=cat_features)
shap_values = model.get_feature_importance(data=pool1, fstr_type='ShapValues', verbose=10000)
print(shap_values.shape)

# %% [markdown]
# Let's look on the prediction of the model for 0-th object. The raw prediction is not the probability, to calculate probability from raw prediction you need to calculate sigmoid(raw_prediction).

# %%
test_objects = [X.iloc[0:1]]

for obj in test_objects:
    print('Probability of class 1 = {:.4f}'.format(model.predict_proba(obj)[0][1]))
    print('Formula raw prediction = {:.4f}'.format(model.predict(obj, prediction_type='RawFormulaVal')[0]))
    print('\n')

# %% [markdown]
# Sum of all shap values are equal to the resulting raw formula predition.
# We can see on the graph that will be output below that there is a base value, which is equal for all the objects.
# And almost all the feature have positive influence on this object. The biggest step to the right is because of the feature called 'MGR_ID'.

# %%
import shap
shap.initjs()
shap.force_plot(shap_values[0,:], X.iloc[0,:])

# %% [markdown]
# ** Question 14: **
#
# What is the most important feature for 91-th object

# %%
most_important_feature = 'FEATURE_NAME'
grader.submit_tag('most_important', most_important_feature)

# %% [markdown]
# ** Question 15: **
#
# Does it have positive or negative influence? Answer 1 if positive and -1 if negative.

# %%
influence_sign = 0
grader.submit_tag('shap_influence', influence_sign)

# %% [markdown]
# You can also view aggregated information about the influences on the whole dataset.

# %%
shap.summary_plot(shap_values, X)

# %% [markdown]
# From this graph you can see that values of MGR_ID and RESOURCE features have a large negative impact for many objects.
# You can also see that RESOURCE has largest positive impact for many objects.

# %% [markdown]
# ## Saving the model

# %% [markdown]
# You can save your model as a binary file. It is also possible to save the model as Python or C++ code.
# If you save the model as a binary file you can then look on the parameters with which the model was trained, including learning_rate and random_seed that are set automatically if you don't specify them.

# %%
my_best_model = CatBoostClassifier(iterations=10)
my_best_model.fit(
    X_train, y_train,
    eval_set=(X_validation, y_validation),
    cat_features=cat_features,
    verbose=False
)
my_best_model.save_model('catboost_model.bin')

# %%
my_best_model.load_model('catboost_model.bin')
print(my_best_model.get_params())
print(my_best_model.random_seed_)
print(my_best_model.learning_rate_)

# %% [markdown]
# ## Hyperparameter tunning

# %% [markdown]
# You can tune the parameters to get better speed or better quality.
# Here is the list of parameters that are important for speed and accuracy.

# %% [markdown]
# ### Training speed

# %% [markdown]
# Here is the list of parameters that are important for speeding up the training.
# Note that changing this parameters might decrease the quality.
# 1. iterations + learning rate
# By default we train for 1000 iterations. You can decrease this number, but if you decrease the number of iterations you need to increase learning rate so that the process converges. We set learning rate by default dependent on number of iterations and on your dataset, so you might just use default learning rate. But if you want to tune it, you need to know - the more iterations you have, the less should be the learning rate.
#
# 2. boosting_type
# By default we use Ordered boosting for smaller datasets where we want to fight overfitting. This is expensive in terms of computations. You can set boosting_type to Plain to disable this.
#
# 3. bootstrap_type
# By default we sample weights from exponential distribution. It is faster to use sampling from Bernoulli distribution. To enable that use bootstrap_type='Bernoulli' + subsample={some value < 1}
#
# 4. one_hot_max_size
# By default we use one-hot encoding only for categorical features with little amount of different values. For all other categorical features we calculate statistics. This is expensive, and one-hot encoding is cheep. So you can speed up the training by setting one_hot_max_size to some bigger value
#
# 5. rsm
# This parameter is very important, because it speeds up the training and does not affect the quality. So you should definitely use it, but only in case if you have hundreds of features.
# If you have little amount of features it's better not to use this parameter.
# If you have many features then the rule is the following: you decrease rsm, for example, you set rsm=0.1. With this rsm value the training needs more iterations to converge. Usually you need about 20% more iterations. But each iteration will be 10x faster. So the resulting training time will be faster even though you will have more trees in the resulting model.
#
# 6. leaf_estimation_iterations
# This parameter is responsible for calculating leaf values after you have already selected tree structure.
# If you have little amount of features, for example 8 or 10 features, then this place starts to be the bottle-neck.
# Default value for this parameter depends on the training objective, you can try setting it to 1 or 5, and if you have little amount of features, this might speed up the training.
#
# 7. max_ctr_complexity
# By default catboost generates categorical feature combinations in a greedy way.
# This is time consuming, you can disable that by setting max_ctr_complexity=1 or by allowing only combinations of 2 features by setting max_ctr_complexity=2.
# This will speed up the training only if you have categorical features.
#
# 8. If you are training the model on GPU, you can try decreasing border_count. This is the number of splits considered for each feature. By default it's set to 128, but you can try setting it to 32. In many cases it will not degrade the quality of the model and will speed up the training by a lot.

# %%
from catboost import CatBoost
fast_model = CatBoostClassifier(
    random_seed=63,
    iterations=150,
    learning_rate=0.01,
    boosting_type='Plain',
    bootstrap_type='Bernoulli',
    subsample=0.5,
    one_hot_max_size=20,
    rsm=0.5,
    leaf_estimation_iterations=5,
    max_ctr_complexity=1,
    border_count=32)

fast_model.fit(
    X_train, y_train,
    cat_features=cat_features,
    logging_level='Silent',
    plot=True
)

# %% [markdown]
# ** Question 16: **
#
# Try tunning the speed of the algorithm. What is the maximum speedup you could get by changing these parameters without decreasing of AUC on best iteration on eval dataset compared to AUC on best iteration after training with default parameters and random seed = 0?
# The answer shoud be a number, for example 2.7 means you got 2.7 times speedup.

# %%
speedup = 0
grader.submit_tag('speedup', speedup)

# %% [markdown]
# ### Accuracy

# %% [markdown]
# The parameters listed below are important to get the best quality of the model. Try changing this parameters to improve the quality of the resulting model

# %%
tunned_model = CatBoostClassifier(
    random_seed=63,
    iterations=1000,
    learning_rate=0.03,
    l2_leaf_reg=3,
    bagging_temperature=1,
    random_strength=1,
    one_hot_max_size=2,
    leaf_estimation_method='Newton',
    depth=6
)
tunned_model.fit(
    X_train, y_train,
    cat_features=cat_features,
    logging_level='Silent',
    eval_set=(X_validation, y_validation),
    plot=True
)

# %% [markdown]
# ** Question 17: **
#
# Try tunning these parameters to make AUC on eval dataset as large as possible. What is the maximum AUC value you have reached?

# %%
final_auc = 0
grader.submit_tag('final_auc', final_auc)

# %%
STUDENT_EMAIL = # EMAIL HERE
STUDENT_TOKEN = # TOKEN HERE
grader.status()

# %%
grader.submit(STUDENT_EMAIL, STUDENT_TOKEN)
